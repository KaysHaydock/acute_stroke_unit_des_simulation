# %% [markdown]
# ## Iteration 3: includes four type of stroke patients and uses in the  AcuteStrokeUnit class to generate arrivals for each type of patient.

# %% [markdown]
# ## **. Patient Admission Sources**
# Patients enter the hospital through **two primary pathways**:
# - **New Admissions**: Direct hospital entry for Stroke, TIA, Complex Neurological, and Other Medical Cases.
#
#
# | Patient Type                     | Admissions (n) | Percentage (%) |
# |----------------------------------|---------------|--------------|
# | Stroke                           | 1,320         | 54%          |
# | Transient Ischemic Attack (TIA)  | 158           | 6%           |
# | Complex Neurological             | 456           | 19%          |
# | Other Medical Cases              | 510           | 21%          |
#
# **Patient admissions are distributed as follows**
#
# | Category                | Mean(Days) |
# |-------------------------|----------------------------|
# | Stroke                  | 1.2                        |
# | TIA (Transient Ischemic Attack) | 9.3                |
# | Complex Neurological    | 3.6                        |
# | Other                   | 3.2                        |

# %% [markdown]
# ## 1. Imports

# %%
import numpy as np
import itertools
import simpy
import os
import sys

# %%
# Add parent directory to path so we can import distribution.py
sys.path.append(os.path.abspath('..'))  # noqa: E402

from distribution import Exponential  # noqa: E402

# %% [markdown]
# ## 2. Constants

# %%
# default mean inter-arrival times(exp)
IAT_STROKE = 1.2
IAT_TIA = 9.3
IAT_COMPLEX_NEURO = 3.6
IAT_OTHER = 3.2

# sampling settings
N_STREAMS = 4
DEFAULT_RND_SET = 0

# Boolean switch to simulation results as the model runs
TRACE = False

# run variables (units = hours)
RUN_LENGTH = 24 * 10

# %% [markdown]
# ## 2. Helper classes and functions

# %%
def trace(msg):
    """
    Turing printing of events on and off.

    Params:
    -------
    msg: str
        string to print to screen.
    """
    if TRACE:
        print(msg)

# %% [markdown]
# ## 3. Experiment class

# %%
class Experiment:
    """
    Encapsulates the concept of an experiment
    for the Acute Stroke Unit simulation.
    Manages parameters, PRNG streams, and results.
    """

    def __init__(
        self,
        random_number_set=0,
        n_streams=4,
        iat_stroke=1.2,
        iat_tia=9.3,
        iat_complex_neuro=3.6,
        iat_other=3.2,
        asu_bed=10,
    ):
        """
        Initialize default parameters.
        """
        # Sampling settings
        self.random_number_set = random_number_set
        self.n_streams = n_streams

        # Model parameters
        self.iat_stroke = iat_stroke
        self.iat_tia = iat_tia
        self.iat_complex_neuro = iat_complex_neuro
        self.iat_other = iat_other
        self.asu_bed = asu_bed

        # Length of stay distributions
        self.length_of_stay = {
            "stroke": (7.4, 8.6),
            "tia": (1.8, 2.3),
            "complex_neuro": (4.0, 5.0),
            "other": (3.8, 5.2),
        }

        # Initialize results storage
        self.init_results_variables()

        # Initialize sampling distributions
        self.init_sampling()

    def set_random_no_set(self, random_number_set):
        """
        Controls the random sampling.

        Parameters:
        ----------
        random_number_set: int
            Controls the set of pseudo-random numbers
            used by the distributions.
        """
        self.random_number_set = random_number_set
        self.init_sampling()

    def init_sampling(self):
        """
        Creates the distributions used by the model and initializes
        the random seeds of each.
        """
        # Produce n non-overlapping streams
        seed_sequence = np.random.SeedSequence(self.random_number_set)
        self.seeds = seed_sequence.spawn(self.n_streams)

        # Inter-arrival time distributions
        self.arrival_stroke = Exponential(
            self.iat_stroke, random_seed=self.seeds[0]
        )
        self.arrival_tia = Exponential(self.iat_tia, random_seed=self.seeds[1])
        self.arrival_complex_neuro = Exponential(
            self.iat_complex_neuro, random_seed=self.seeds[2]
        )
        self.arrival_other = Exponential(
            self.iat_other, random_seed=self.seeds[3]
        )

    def init_results_variables(self):
        """
        Initializes all the experiment variables used in results collection.
        """
        self.results = {}
        self.results["n_stroke"] = 0
        self.results["n_tia"] = 0
        self.results["n_complex_neuro"] = 0
        self.results["n_other"] = 0
        self.results["n_patients"] = 0

# %% [markdown]
# ## 3. Patient Class

# %%
class Patient:
    """
    Represents a patient in the system.
    """

    def __init__(self, patient_id, env, args, acute_stroke_unit):
        self.patient_id = patient_id
        self.env = env
        self.args = args
        self.acute_stroke_unit = acute_stroke_unit  # Pass the ASU instance

    def treatment(self):
        """
        Simulates patient treatment process.
        """
        arrival_time = self.env.now
        with self.acute_stroke_unit.asu_bed.request() as request:
            yield request
            waiting_time = self.env.now - arrival_time
            trace(
                f"Patient {self.patient_id}"
                f" gets a bed at {self.env.now:.2f} days "
                f" waiting {waiting_time:.2f} days"

            )

# %% [markdown]
# ### 4. Acute Stroke Unit Class

# %%
class AcuteStrokeUnit:
    """
    Models the Acute Stroke Unit (ASU) in the hospital.

    Parameters:
    - env: SimPy environment
    - args: Scenario object containing hospital parameters
    """

    def __init__(self, env, args):
        self.env = env
        self.patient_count = 0
        self.args = args
        self.asu_bed = simpy.Resource(env, capacity=args.asu_bed)

    def stroke_arrivals_generator(self):
        """
        Arrival process for stroke patients.
        """
        for patient_count in itertools.count(start=1):
            inter_arrival_time = self.args.arrival_stroke.sample()
            yield self.env.timeout(inter_arrival_time)

            self.args.results["n_stroke"] = patient_count
            self.args.results["n_patients"] += 1
            trace(f"{self.env.now:.2f}: STROKE arrival.")

            new_patient = Patient(patient_count, self.env, self.args, self)
            self.env.process(new_patient.treatment())

    def tia_arrivals_generator(self):
        """
        Arrival process for TIA patients.
        """
        for patient_count in itertools.count(start=1):
            inter_arrival_time = self.args.arrival_tia.sample()
            yield self.env.timeout(inter_arrival_time)

            self.args.results["n_tia"] = patient_count
            self.args.results["n_patients"] += 1
            trace(f"{self.env.now:.2f}: TIA arrival.")

            new_patient = Patient(patient_count, self.env, self.args, self)
            self.env.process(new_patient.treatment())

    def complex_neuro_arrivals_generator(self):
        """
        Arrival process for complex neuro cases.
        """
        for patient_count in itertools.count(start=1):
            inter_arrival_time = self.args.arrival_complex_neuro.sample()
            yield self.env.timeout(inter_arrival_time)

            self.args.results["n_complex_neuro"] = patient_count
            self.args.results["n_patients"] += 1
            trace(f"{self.env.now:.2f}: COMPLEX NEURO arrival.")

            new_patient = Patient(patient_count, self.env, self.args, self)
            self.env.process(new_patient.treatment())

    def other_arrivals_generator(self):
        """
        Arrival process for other neurological cases.
        """
        for patient_count in itertools.count(start=1):
            inter_arrival_time = self.args.arrival_other.sample()
            yield self.env.timeout(inter_arrival_time)

            self.args.results["n_other"] = patient_count
            self.args.results["n_patients"] += 1
            trace(f"{self.env.now:.2f}: OTHER arrival.")

            new_patient = Patient(patient_count, self.env, self.args, self)
            self.env.process(new_patient.treatment())

# %% [markdown]
# ## 4. A function per arrival source
#
# The first approach we will use is creating an arrival generator per source.  There will be some code redundancy, but it will a clear design for others to understand.

# %% [markdown]
# ## 5. Single run function

# %%
def single_run(experiment, rep=0, run_length=RUN_LENGTH):
    """
    Perform a single run of the model and return the results

    Parameters:
    -----------

    experiment: Experiment
        The experiment/parameters to use with model

    rep: int
        The replication number.

    run_length: float, optional (default=RUN_LENGTH)
        The run length of the model
    """

    # reset all results variables to zero and empty
    experiment.init_results_variables()

    # set random number set to the replication no.
    # this controls sampling for the run.
    experiment.set_random_no_set(rep)

    # environment is (re)created inside single run
    env = simpy.Environment()
    asu = AcuteStrokeUnit(env, experiment)  # Create ASU instance

    # we pass all arrival generators to simpy
    env.process(asu.stroke_arrivals_generator())
    env.process(asu.tia_arrivals_generator())
    env.process(asu.complex_neuro_arrivals_generator())
    env.process(asu.other_arrivals_generator())

    # run for warm-up + results collection period
    env.run(until=run_length)

    # return the count of the arrivals
    return experiment.results

# %%
TRACE = True
experiment = Experiment()
results = single_run(experiment)
results
# Out:
# 3.95: STROKE arrival.
# Patient 1 gets a bed at 3.95 days  waiting 0.00 days
# 4.64: OTHER arrival.
# Patient 1 gets a bed at 4.64 days  waiting 0.00 days
# 4.87: STROKE arrival.
# Patient 2 gets a bed at 4.87 days  waiting 0.00 days
# 4.95: OTHER arrival.
# Patient 2 gets a bed at 4.95 days  waiting 0.00 days
# 5.51: COMPLEX NEURO arrival.
# Patient 1 gets a bed at 5.51 days  waiting 0.00 days
# 5.92: COMPLEX NEURO arrival.
# Patient 2 gets a bed at 5.92 days  waiting 0.00 days
# 6.37: STROKE arrival.
# Patient 3 gets a bed at 6.37 days  waiting 0.00 days
# 6.64: STROKE arrival.
# Patient 4 gets a bed at 6.64 days  waiting 0.00 days
# 6.91: STROKE arrival.
# Patient 5 gets a bed at 6.91 days  waiting 0.00 days
# 7.47: TIA arrival.
# Patient 1 gets a bed at 7.47 days  waiting 0.00 days
# 9.07: STROKE arrival.
# Patient 6 gets a bed at 9.07 days  waiting 0.00 days
# 9.12: OTHER arrival.
# Patient 3 gets a bed at 9.12 days  waiting 0.00 days
# 9.15: STROKE arrival.
# Patient 7 gets a bed at 9.15 days  waiting 0.00 days
# 9.34: OTHER arrival.
# Patient 4 gets a bed at 9.34 days  waiting 0.00 days
# 9.83: OTHER arrival.
# Patient 5 gets a bed at 9.83 days  waiting 0.00 days
# 10.16: COMPLEX NEURO arrival.
# Patient 3 gets a bed at 10.16 days  waiting 0.00 days
# 10.23: STROKE arrival.
# Patient 8 gets a bed at 10.23 days  waiting 0.00 days
# 10.44: OTHER arrival.
# Patient 6 gets a bed at 10.44 days  waiting 0.00 days
# 10.58: STROKE arrival.
# Patient 9 gets a bed at 10.58 days  waiting 0.00 days
# 11.02: TIA arrival.
# Patient 2 gets a bed at 11.02 days  waiting 0.00 days
# 13.34: STROKE arrival.
# Patient 10 gets a bed at 13.34 days  waiting 0.00 days
# 14.41: TIA arrival.
# Patient 3 gets a bed at 14.41 days  waiting 0.00 days
# 15.57: STROKE arrival.
# Patient 11 gets a bed at 15.57 days  waiting 0.00 days
# 15.59: STROKE arrival.
# Patient 12 gets a bed at 15.59 days  waiting 0.00 days
# 17.95: COMPLEX NEURO arrival.
# Patient 4 gets a bed at 17.95 days  waiting 0.00 days
# 19.17: OTHER arrival.
# Patient 7 gets a bed at 19.17 days  waiting 0.00 days
# 19.33: TIA arrival.
# Patient 4 gets a bed at 19.33 days  waiting 0.00 days
# 19.34: COMPLEX NEURO arrival.
# Patient 5 gets a bed at 19.34 days  waiting 0.00 days
# 21.13: COMPLEX NEURO arrival.
# Patient 6 gets a bed at 21.13 days  waiting 0.00 days
# 22.30: STROKE arrival.
# Patient 13 gets a bed at 22.30 days  waiting 0.00 days
# 22.36: COMPLEX NEURO arrival.
# Patient 7 gets a bed at 22.36 days  waiting 0.00 days
# 23.26: STROKE arrival.
# Patient 14 gets a bed at 23.26 days  waiting 0.00 days
# 23.68: STROKE arrival.
# Patient 15 gets a bed at 23.68 days  waiting 0.00 days
# 25.78: COMPLEX NEURO arrival.
# Patient 8 gets a bed at 25.78 days  waiting 0.00 days
# 26.04: STROKE arrival.
# Patient 16 gets a bed at 26.04 days  waiting 0.00 days
# 26.82: OTHER arrival.
# Patient 8 gets a bed at 26.82 days  waiting 0.00 days
# 26.93: STROKE arrival.
# Patient 17 gets a bed at 26.93 days  waiting 0.00 days
# 26.94: STROKE arrival.
# Patient 18 gets a bed at 26.94 days  waiting 0.00 days
# 26.99: OTHER arrival.
# Patient 9 gets a bed at 26.99 days  waiting 0.00 days
# 27.94: STROKE arrival.
# Patient 19 gets a bed at 27.94 days  waiting 0.00 days
# 28.68: STROKE arrival.
# Patient 20 gets a bed at 28.68 days  waiting 0.00 days
# 29.00: COMPLEX NEURO arrival.
# Patient 9 gets a bed at 29.00 days  waiting 0.00 days
# 29.41: STROKE arrival.
# Patient 21 gets a bed at 29.41 days  waiting 0.00 days
# 29.88: COMPLEX NEURO arrival.
# Patient 10 gets a bed at 29.88 days  waiting 0.00 days
# 29.91: COMPLEX NEURO arrival.
# Patient 11 gets a bed at 29.91 days  waiting 0.00 days
# 30.20: OTHER arrival.
# Patient 10 gets a bed at 30.20 days  waiting 0.00 days
# 31.43: COMPLEX NEURO arrival.
# Patient 12 gets a bed at 31.43 days  waiting 0.00 days
# 32.81: STROKE arrival.
# Patient 22 gets a bed at 32.81 days  waiting 0.00 days
# 33.10: STROKE arrival.
# Patient 23 gets a bed at 33.10 days  waiting 0.00 days
# 34.53: COMPLEX NEURO arrival.
# Patient 13 gets a bed at 34.53 days  waiting 0.00 days
# 36.10: STROKE arrival.
# Patient 24 gets a bed at 36.10 days  waiting 0.00 days
# 36.43: COMPLEX NEURO arrival.
# Patient 14 gets a bed at 36.43 days  waiting 0.00 days
# 36.49: STROKE arrival.
# Patient 25 gets a bed at 36.49 days  waiting 0.00 days
# 37.46: OTHER arrival.
# Patient 11 gets a bed at 37.46 days  waiting 0.00 days
# 38.03: OTHER arrival.
# Patient 12 gets a bed at 38.03 days  waiting 0.00 days
# 38.35: STROKE arrival.
# Patient 26 gets a bed at 38.35 days  waiting 0.00 days
# 39.62: STROKE arrival.
# Patient 27 gets a bed at 39.62 days  waiting 0.00 days
# 40.09: STROKE arrival.
# Patient 28 gets a bed at 40.09 days  waiting 0.00 days
# 40.22: OTHER arrival.
# Patient 13 gets a bed at 40.22 days  waiting 0.00 days
# 40.90: STROKE arrival.
# Patient 29 gets a bed at 40.90 days  waiting 0.00 days
# 41.23: OTHER arrival.
# Patient 14 gets a bed at 41.23 days  waiting 0.00 days
# 41.76: COMPLEX NEURO arrival.
# Patient 15 gets a bed at 41.76 days  waiting 0.00 days
# 42.78: COMPLEX NEURO arrival.
# Patient 16 gets a bed at 42.78 days  waiting 0.00 days
# 43.24: STROKE arrival.
# Patient 30 gets a bed at 43.24 days  waiting 0.00 days
# 45.26: TIA arrival.
# Patient 5 gets a bed at 45.26 days  waiting 0.00 days
# 46.10: STROKE arrival.
# Patient 31 gets a bed at 46.10 days  waiting 0.00 days
# 46.29: OTHER arrival.
# Patient 15 gets a bed at 46.29 days  waiting 0.00 days
# 46.63: OTHER arrival.
# Patient 16 gets a bed at 46.63 days  waiting 0.00 days
# 47.10: STROKE arrival.
# Patient 32 gets a bed at 47.10 days  waiting 0.00 days
# 48.92: COMPLEX NEURO arrival.
# Patient 17 gets a bed at 48.92 days  waiting 0.00 days
# 49.60: STROKE arrival.
# Patient 33 gets a bed at 49.60 days  waiting 0.00 days
# 50.43: STROKE arrival.
# Patient 34 gets a bed at 50.43 days  waiting 0.00 days
# 50.99: STROKE arrival.
# Patient 35 gets a bed at 50.99 days  waiting 0.00 days
# 51.22: OTHER arrival.
# Patient 17 gets a bed at 51.22 days  waiting 0.00 days
# 52.18: COMPLEX NEURO arrival.
# Patient 18 gets a bed at 52.18 days  waiting 0.00 days
# 52.44: STROKE arrival.
# Patient 36 gets a bed at 52.44 days  waiting 0.00 days
# 52.54: STROKE arrival.
# Patient 37 gets a bed at 52.54 days  waiting 0.00 days
# 52.95: STROKE arrival.
# Patient 38 gets a bed at 52.95 days  waiting 0.00 days
# 53.21: OTHER arrival.
# Patient 18 gets a bed at 53.21 days  waiting 0.00 days
# 54.15: STROKE arrival.
# Patient 39 gets a bed at 54.15 days  waiting 0.00 days
# 54.43: STROKE arrival.
# Patient 40 gets a bed at 54.43 days  waiting 0.00 days
# 55.87: STROKE arrival.
# Patient 41 gets a bed at 55.87 days  waiting 0.00 days
# 56.72: STROKE arrival.
# Patient 42 gets a bed at 56.72 days  waiting 0.00 days
# 59.60: OTHER arrival.
# Patient 19 gets a bed at 59.60 days  waiting 0.00 days
# 60.46: OTHER arrival.
# Patient 20 gets a bed at 60.46 days  waiting 0.00 days
# 61.07: OTHER arrival.
# Patient 21 gets a bed at 61.07 days  waiting 0.00 days
# 61.79: STROKE arrival.
# Patient 43 gets a bed at 61.79 days  waiting 0.00 days
# 61.83: STROKE arrival.
# Patient 44 gets a bed at 61.83 days  waiting 0.00 days
# 62.01: OTHER arrival.
# Patient 22 gets a bed at 62.01 days  waiting 0.00 days
# 63.50: TIA arrival.
# Patient 6 gets a bed at 63.50 days  waiting 0.00 days
# 64.45: OTHER arrival.
# Patient 23 gets a bed at 64.45 days  waiting 0.00 days
# 64.90: OTHER arrival.
# Patient 24 gets a bed at 64.90 days  waiting 0.00 days
# 65.49: STROKE arrival.
# Patient 45 gets a bed at 65.49 days  waiting 0.00 days
# 65.75: STROKE arrival.
# Patient 46 gets a bed at 65.75 days  waiting 0.00 days
# 65.84: STROKE arrival.
# Patient 47 gets a bed at 65.84 days  waiting 0.00 days
# 66.95: STROKE arrival.
# Patient 48 gets a bed at 66.95 days  waiting 0.00 days
# 67.95: COMPLEX NEURO arrival.
# Patient 19 gets a bed at 67.95 days  waiting 0.00 days
# 68.11: OTHER arrival.
# Patient 25 gets a bed at 68.11 days  waiting 0.00 days
# 68.64: COMPLEX NEURO arrival.
# Patient 20 gets a bed at 68.64 days  waiting 0.00 days
# 69.42: STROKE arrival.
# Patient 49 gets a bed at 69.42 days  waiting 0.00 days
# 69.69: COMPLEX NEURO arrival.
# Patient 21 gets a bed at 69.69 days  waiting 0.00 days
# 69.80: COMPLEX NEURO arrival.
# Patient 22 gets a bed at 69.80 days  waiting 0.00 days
# 70.28: STROKE arrival.
# Patient 50 gets a bed at 70.28 days  waiting 0.00 days
# 70.61: STROKE arrival.
# Patient 51 gets a bed at 70.61 days  waiting 0.00 days
# 71.27: STROKE arrival.
# Patient 52 gets a bed at 71.27 days  waiting 0.00 days
# 71.56: STROKE arrival.
# Patient 53 gets a bed at 71.56 days  waiting 0.00 days
# 72.10: COMPLEX NEURO arrival.
# Patient 23 gets a bed at 72.10 days  waiting 0.00 days
# 72.33: TIA arrival.
# Patient 7 gets a bed at 72.33 days  waiting 0.00 days
# 73.86: STROKE arrival.
# Patient 54 gets a bed at 73.86 days  waiting 0.00 days
# 74.40: STROKE arrival.
# Patient 55 gets a bed at 74.40 days  waiting 0.00 days
# 74.79: STROKE arrival.
# Patient 56 gets a bed at 74.79 days  waiting 0.00 days
# 75.34: STROKE arrival.
# Patient 57 gets a bed at 75.34 days  waiting 0.00 days
# 76.85: STROKE arrival.
# Patient 58 gets a bed at 76.85 days  waiting 0.00 days
# 77.94: STROKE arrival.
# Patient 59 gets a bed at 77.94 days  waiting 0.00 days
# 78.04: STROKE arrival.
# Patient 60 gets a bed at 78.04 days  waiting 0.00 days
# 79.18: STROKE arrival.
# Patient 61 gets a bed at 79.18 days  waiting 0.00 days
# 80.45: STROKE arrival.
# Patient 62 gets a bed at 80.45 days  waiting 0.00 days
# 80.80: STROKE arrival.
# Patient 63 gets a bed at 80.80 days  waiting 0.00 days
# 81.49: COMPLEX NEURO arrival.
# Patient 24 gets a bed at 81.49 days  waiting 0.00 days
# 82.35: STROKE arrival.
# Patient 64 gets a bed at 82.35 days  waiting 0.00 days
# 83.19: STROKE arrival.
# Patient 65 gets a bed at 83.19 days  waiting 0.00 days
# 83.41: OTHER arrival.
# Patient 26 gets a bed at 83.41 days  waiting 0.00 days
# 84.18: STROKE arrival.
# Patient 66 gets a bed at 84.18 days  waiting 0.00 days
# 84.38: OTHER arrival.
# Patient 27 gets a bed at 84.38 days  waiting 0.00 days
# 85.15: STROKE arrival.
# Patient 67 gets a bed at 85.15 days  waiting 0.00 days
# 85.64: STROKE arrival.
# Patient 68 gets a bed at 85.64 days  waiting 0.00 days
# 87.83: STROKE arrival.
# Patient 69 gets a bed at 87.83 days  waiting 0.00 days
# 88.02: STROKE arrival.
# Patient 70 gets a bed at 88.02 days  waiting 0.00 days
# 88.23: STROKE arrival.
# Patient 71 gets a bed at 88.23 days  waiting 0.00 days
# 88.43: STROKE arrival.
# Patient 72 gets a bed at 88.43 days  waiting 0.00 days
# 88.61: STROKE arrival.
# Patient 73 gets a bed at 88.61 days  waiting 0.00 days
# 88.93: COMPLEX NEURO arrival.
# Patient 25 gets a bed at 88.93 days  waiting 0.00 days
# 89.75: STROKE arrival.
# Patient 74 gets a bed at 89.75 days  waiting 0.00 days
# 89.77: COMPLEX NEURO arrival.
# Patient 26 gets a bed at 89.77 days  waiting 0.00 days
# 91.03: STROKE arrival.
# Patient 75 gets a bed at 91.03 days  waiting 0.00 days
# 91.05: COMPLEX NEURO arrival.
# Patient 27 gets a bed at 91.05 days  waiting 0.00 days
# 91.71: STROKE arrival.
# Patient 76 gets a bed at 91.71 days  waiting 0.00 days
# 93.41: OTHER arrival.
# Patient 28 gets a bed at 93.41 days  waiting 0.00 days
# 93.49: STROKE arrival.
# Patient 77 gets a bed at 93.49 days  waiting 0.00 days
# 94.15: STROKE arrival.
# Patient 78 gets a bed at 94.15 days  waiting 0.00 days
# 94.46: OTHER arrival.
# Patient 29 gets a bed at 94.46 days  waiting 0.00 days
# 94.86: OTHER arrival.
# Patient 30 gets a bed at 94.86 days  waiting 0.00 days
# 95.35: OTHER arrival.
# Patient 31 gets a bed at 95.35 days  waiting 0.00 days
# 95.99: STROKE arrival.
# Patient 79 gets a bed at 95.99 days  waiting 0.00 days
# 96.26: COMPLEX NEURO arrival.
# Patient 28 gets a bed at 96.26 days  waiting 0.00 days
# 98.45: STROKE arrival.
# Patient 80 gets a bed at 98.45 days  waiting 0.00 days
# 98.47: OTHER arrival.
# Patient 32 gets a bed at 98.47 days  waiting 0.00 days
# 99.68: STROKE arrival.
# Patient 81 gets a bed at 99.68 days  waiting 0.00 days
# 99.81: STROKE arrival.
# Patient 82 gets a bed at 99.81 days  waiting 0.00 days
# 100.39: STROKE arrival.
# Patient 83 gets a bed at 100.39 days  waiting 0.00 days
# 100.42: COMPLEX NEURO arrival.
# Patient 29 gets a bed at 100.42 days  waiting 0.00 days
# 101.27: STROKE arrival.
# Patient 84 gets a bed at 101.27 days  waiting 0.00 days
# 103.55: OTHER arrival.
# Patient 33 gets a bed at 103.55 days  waiting 0.00 days
# 104.27: STROKE arrival.
# Patient 85 gets a bed at 104.27 days  waiting 0.00 days
# 105.50: STROKE arrival.
# Patient 86 gets a bed at 105.50 days  waiting 0.00 days
# 105.84: STROKE arrival.
# Patient 87 gets a bed at 105.84 days  waiting 0.00 days
# 107.39: OTHER arrival.
# Patient 34 gets a bed at 107.39 days  waiting 0.00 days
# 109.04: STROKE arrival.
# Patient 88 gets a bed at 109.04 days  waiting 0.00 days
# 109.98: OTHER arrival.
# Patient 35 gets a bed at 109.98 days  waiting 0.00 days
# 111.08: TIA arrival.
# Patient 8 gets a bed at 111.08 days  waiting 0.00 days
# 111.23: OTHER arrival.
# Patient 36 gets a bed at 111.23 days  waiting 0.00 days
# 111.80: STROKE arrival.
# Patient 89 gets a bed at 111.80 days  waiting 0.00 days
# 112.10: STROKE arrival.
# Patient 90 gets a bed at 112.10 days  waiting 0.00 days
# 112.14: OTHER arrival.
# Patient 37 gets a bed at 112.14 days  waiting 0.00 days
# 112.88: STROKE arrival.
# Patient 91 gets a bed at 112.88 days  waiting 0.00 days
# 113.74: STROKE arrival.
# Patient 92 gets a bed at 113.74 days  waiting 0.00 days
# 114.63: OTHER arrival.
# Patient 38 gets a bed at 114.63 days  waiting 0.00 days
# 114.68: STROKE arrival.
# Patient 93 gets a bed at 114.68 days  waiting 0.00 days
# 115.46: STROKE arrival.
# Patient 94 gets a bed at 115.46 days  waiting 0.00 days
# 116.25: OTHER arrival.
# Patient 39 gets a bed at 116.25 days  waiting 0.00 days
# 116.54: TIA arrival.
# Patient 9 gets a bed at 116.54 days  waiting 0.00 days
# 116.90: STROKE arrival.
# Patient 95 gets a bed at 116.90 days  waiting 0.00 days
# 117.17: STROKE arrival.
# Patient 96 gets a bed at 117.17 days  waiting 0.00 days
# 117.45: COMPLEX NEURO arrival.
# Patient 30 gets a bed at 117.45 days  waiting 0.00 days
# 118.24: COMPLEX NEURO arrival.
# Patient 31 gets a bed at 118.24 days  waiting 0.00 days
# 118.43: STROKE arrival.
# Patient 97 gets a bed at 118.43 days  waiting 0.00 days
# 119.36: COMPLEX NEURO arrival.
# Patient 32 gets a bed at 119.36 days  waiting 0.00 days
# 122.22: OTHER arrival.
# Patient 40 gets a bed at 122.22 days  waiting 0.00 days
# 122.73: STROKE arrival.
# Patient 98 gets a bed at 122.73 days  waiting 0.00 days
# 122.79: STROKE arrival.
# Patient 99 gets a bed at 122.79 days  waiting 0.00 days
# 123.33: STROKE arrival.
# Patient 100 gets a bed at 123.33 days  waiting 0.00 days
# 123.53: COMPLEX NEURO arrival.
# Patient 33 gets a bed at 123.53 days  waiting 0.00 days
# 124.00: OTHER arrival.
# Patient 41 gets a bed at 124.00 days  waiting 0.00 days
# 126.06: STROKE arrival.
# Patient 101 gets a bed at 126.06 days  waiting 0.00 days
# 127.08: STROKE arrival.
# Patient 102 gets a bed at 127.08 days  waiting 0.00 days
# 128.81: COMPLEX NEURO arrival.
# Patient 34 gets a bed at 128.81 days  waiting 0.00 days
# 129.24: STROKE arrival.
# Patient 103 gets a bed at 129.24 days  waiting 0.00 days
# 131.64: STROKE arrival.
# Patient 104 gets a bed at 131.64 days  waiting 0.00 days
# 132.77: STROKE arrival.
# Patient 105 gets a bed at 132.77 days  waiting 0.00 days
# 134.39: STROKE arrival.
# Patient 106 gets a bed at 134.39 days  waiting 0.00 days
# 134.40: STROKE arrival.
# Patient 107 gets a bed at 134.40 days  waiting 0.00 days
# 135.78: STROKE arrival.
# Patient 108 gets a bed at 135.78 days  waiting 0.00 days
# 136.52: STROKE arrival.
# Patient 109 gets a bed at 136.52 days  waiting 0.00 days
# 136.95: STROKE arrival.
# Patient 110 gets a bed at 136.95 days  waiting 0.00 days
# 136.97: OTHER arrival.
# Patient 42 gets a bed at 136.97 days  waiting 0.00 days
# 137.52: STROKE arrival.
# Patient 111 gets a bed at 137.52 days  waiting 0.00 days
# 139.11: STROKE arrival.
# Patient 112 gets a bed at 139.11 days  waiting 0.00 days
# 139.13: STROKE arrival.
# Patient 113 gets a bed at 139.13 days  waiting 0.00 days
# 141.71: COMPLEX NEURO arrival.
# Patient 35 gets a bed at 141.71 days  waiting 0.00 days
# 142.47: TIA arrival.
# Patient 10 gets a bed at 142.47 days  waiting 0.00 days
# 143.71: COMPLEX NEURO arrival.
# Patient 36 gets a bed at 143.71 days  waiting 0.00 days
# 143.79: STROKE arrival.
# Patient 114 gets a bed at 143.79 days  waiting 0.00 days
# 145.45: OTHER arrival.
# Patient 43 gets a bed at 145.45 days  waiting 0.00 days
# 147.54: COMPLEX NEURO arrival.
# Patient 37 gets a bed at 147.54 days  waiting 0.00 days
# 147.87: OTHER arrival.
# Patient 44 gets a bed at 147.87 days  waiting 0.00 days
# 147.93: STROKE arrival.
# Patient 115 gets a bed at 147.93 days  waiting 0.00 days
# 149.28: STROKE arrival.
# Patient 116 gets a bed at 149.28 days  waiting 0.00 days
# 149.51: COMPLEX NEURO arrival.
# Patient 38 gets a bed at 149.51 days  waiting 0.00 days
# 150.01: OTHER arrival.
# Patient 45 gets a bed at 150.01 days  waiting 0.00 days
# 151.16: OTHER arrival.
# Patient 46 gets a bed at 151.16 days  waiting 0.00 days
# 151.35: STROKE arrival.
# Patient 117 gets a bed at 151.35 days  waiting 0.00 days
# 152.17: STROKE arrival.
# Patient 118 gets a bed at 152.17 days  waiting 0.00 days
# 152.52: STROKE arrival.
# Patient 119 gets a bed at 152.52 days  waiting 0.00 days
# 153.89: STROKE arrival.
# Patient 120 gets a bed at 153.89 days  waiting 0.00 days
# 154.08: OTHER arrival.
# Patient 47 gets a bed at 154.08 days  waiting 0.00 days
# 156.58: STROKE arrival.
# Patient 121 gets a bed at 156.58 days  waiting 0.00 days
# 157.00: STROKE arrival.
# Patient 122 gets a bed at 157.00 days  waiting 0.00 days
# 157.64: STROKE arrival.
# Patient 123 gets a bed at 157.64 days  waiting 0.00 days
# 158.73: STROKE arrival.
# Patient 124 gets a bed at 158.73 days  waiting 0.00 days
# 161.09: OTHER arrival.
# Patient 48 gets a bed at 161.09 days  waiting 0.00 days
# 161.45: OTHER arrival.
# Patient 49 gets a bed at 161.45 days  waiting 0.00 days
# 161.70: STROKE arrival.
# Patient 125 gets a bed at 161.70 days  waiting 0.00 days
# 163.94: STROKE arrival.
# Patient 126 gets a bed at 163.94 days  waiting 0.00 days
# 165.64: TIA arrival.
# Patient 11 gets a bed at 165.64 days  waiting 0.00 days
# 165.83: STROKE arrival.
# Patient 127 gets a bed at 165.83 days  waiting 0.00 days
# 166.88: COMPLEX NEURO arrival.
# Patient 39 gets a bed at 166.88 days  waiting 0.00 days
# 166.96: STROKE arrival.
# Patient 128 gets a bed at 166.96 days  waiting 0.00 days
# 167.20: COMPLEX NEURO arrival.
# Patient 40 gets a bed at 167.20 days  waiting 0.00 days
# 167.30: OTHER arrival.
# Patient 50 gets a bed at 167.30 days  waiting 0.00 days
# 167.46: STROKE arrival.
# Patient 129 gets a bed at 167.46 days  waiting 0.00 days
# 169.61: OTHER arrival.
# Patient 51 gets a bed at 169.61 days  waiting 0.00 days
# 169.67: COMPLEX NEURO arrival.
# Patient 41 gets a bed at 169.67 days  waiting 0.00 days
# 170.01: STROKE arrival.
# Patient 130 gets a bed at 170.01 days  waiting 0.00 days
# 170.23: COMPLEX NEURO arrival.
# Patient 42 gets a bed at 170.23 days  waiting 0.00 days
# 170.99: COMPLEX NEURO arrival.
# Patient 43 gets a bed at 170.99 days  waiting 0.00 days
# 171.39: STROKE arrival.
# Patient 131 gets a bed at 171.39 days  waiting 0.00 days
# 172.16: COMPLEX NEURO arrival.
# Patient 44 gets a bed at 172.16 days  waiting 0.00 days
# 172.31: STROKE arrival.
# Patient 132 gets a bed at 172.31 days  waiting 0.00 days
# 172.87: STROKE arrival.
# Patient 133 gets a bed at 172.87 days  waiting 0.00 days
# 175.03: OTHER arrival.
# Patient 52 gets a bed at 175.03 days  waiting 0.00 days
# 176.01: STROKE arrival.
# Patient 134 gets a bed at 176.01 days  waiting 0.00 days
# 176.33: STROKE arrival.
# Patient 135 gets a bed at 176.33 days  waiting 0.00 days
# 177.06: STROKE arrival.
# Patient 136 gets a bed at 177.06 days  waiting 0.00 days
# 177.08: OTHER arrival.
# Patient 53 gets a bed at 177.08 days  waiting 0.00 days
# 177.62: OTHER arrival.
# Patient 54 gets a bed at 177.62 days  waiting 0.00 days
# 178.37: OTHER arrival.
# Patient 55 gets a bed at 178.37 days  waiting 0.00 days
# 179.75: OTHER arrival.
# Patient 56 gets a bed at 179.75 days  waiting 0.00 days
# 180.06: STROKE arrival.
# Patient 137 gets a bed at 180.06 days  waiting 0.00 days
# 180.13: OTHER arrival.
# Patient 57 gets a bed at 180.13 days  waiting 0.00 days
# 182.45: TIA arrival.
# Patient 12 gets a bed at 182.45 days  waiting 0.00 days
# 184.62: STROKE arrival.
# Patient 138 gets a bed at 184.62 days  waiting 0.00 days
# 185.34: TIA arrival.
# Patient 13 gets a bed at 185.34 days  waiting 0.00 days
# 186.40: COMPLEX NEURO arrival.
# Patient 45 gets a bed at 186.40 days  waiting 0.00 days
# 186.71: COMPLEX NEURO arrival.
# Patient 46 gets a bed at 186.71 days  waiting 0.00 days
# 186.97: STROKE arrival.
# Patient 139 gets a bed at 186.97 days  waiting 0.00 days
# 188.35: STROKE arrival.
# Patient 140 gets a bed at 188.35 days  waiting 0.00 days
# 188.42: OTHER arrival.
# Patient 58 gets a bed at 188.42 days  waiting 0.00 days
# 188.58: OTHER arrival.
# Patient 59 gets a bed at 188.58 days  waiting 0.00 days
# 190.35: STROKE arrival.
# Patient 141 gets a bed at 190.35 days  waiting 0.00 days
# 192.00: STROKE arrival.
# Patient 142 gets a bed at 192.00 days  waiting 0.00 days
# 192.80: OTHER arrival.
# Patient 60 gets a bed at 192.80 days  waiting 0.00 days
# 192.95: STROKE arrival.
# Patient 143 gets a bed at 192.95 days  waiting 0.00 days
# 193.21: STROKE arrival.
# Patient 144 gets a bed at 193.21 days  waiting 0.00 days
# 194.21: STROKE arrival.
# Patient 145 gets a bed at 194.21 days  waiting 0.00 days
# 194.27: STROKE arrival.
# Patient 146 gets a bed at 194.27 days  waiting 0.00 days
# 194.76: STROKE arrival.
# Patient 147 gets a bed at 194.76 days  waiting 0.00 days
# 195.19: STROKE arrival.
# Patient 148 gets a bed at 195.19 days  waiting 0.00 days
# 195.34: STROKE arrival.
# Patient 149 gets a bed at 195.34 days  waiting 0.00 days
# 195.84: STROKE arrival.
# Patient 150 gets a bed at 195.84 days  waiting 0.00 days
# 196.70: STROKE arrival.
# Patient 151 gets a bed at 196.70 days  waiting 0.00 days
# 196.97: STROKE arrival.
# Patient 152 gets a bed at 196.97 days  waiting 0.00 days
# 197.08: STROKE arrival.
# Patient 153 gets a bed at 197.08 days  waiting 0.00 days
# 197.70: STROKE arrival.
# Patient 154 gets a bed at 197.70 days  waiting 0.00 days
# 198.13: STROKE arrival.
# Patient 155 gets a bed at 198.13 days  waiting 0.00 days
# 198.22: OTHER arrival.
# Patient 61 gets a bed at 198.22 days  waiting 0.00 days
# 198.56: STROKE arrival.
# Patient 156 gets a bed at 198.56 days  waiting 0.00 days
# 199.36: STROKE arrival.
# Patient 157 gets a bed at 199.36 days  waiting 0.00 days
# 199.83: STROKE arrival.
# Patient 158 gets a bed at 199.83 days  waiting 0.00 days
# 201.08: STROKE arrival.
# Patient 159 gets a bed at 201.08 days  waiting 0.00 days
# 201.21: STROKE arrival.
# Patient 160 gets a bed at 201.21 days  waiting 0.00 days
# 201.88: STROKE arrival.
# Patient 161 gets a bed at 201.88 days  waiting 0.00 days
# 202.43: OTHER arrival.
# Patient 62 gets a bed at 202.43 days  waiting 0.00 days
# 202.52: COMPLEX NEURO arrival.
# Patient 47 gets a bed at 202.52 days  waiting 0.00 days
# 204.63: STROKE arrival.
# Patient 162 gets a bed at 204.63 days  waiting 0.00 days
# 205.04: STROKE arrival.
# Patient 163 gets a bed at 205.04 days  waiting 0.00 days
# 205.31: STROKE arrival.
# Patient 164 gets a bed at 205.31 days  waiting 0.00 days
# 206.19: STROKE arrival.
# Patient 165 gets a bed at 206.19 days  waiting 0.00 days
# 208.25: COMPLEX NEURO arrival.
# Patient 48 gets a bed at 208.25 days  waiting 0.00 days
# 208.77: COMPLEX NEURO arrival.
# Patient 49 gets a bed at 208.77 days  waiting 0.00 days
# 209.17: STROKE arrival.
# Patient 166 gets a bed at 209.17 days  waiting 0.00 days
# 210.12: STROKE arrival.
# Patient 167 gets a bed at 210.12 days  waiting 0.00 days
# 210.20: STROKE arrival.
# Patient 168 gets a bed at 210.20 days  waiting 0.00 days
# 210.21: TIA arrival.
# Patient 14 gets a bed at 210.21 days  waiting 0.00 days
# 210.80: OTHER arrival.
# Patient 63 gets a bed at 210.80 days  waiting 0.00 days
# 210.91: TIA arrival.
# Patient 15 gets a bed at 210.91 days  waiting 0.00 days
# 211.40: TIA arrival.
# Patient 16 gets a bed at 211.40 days  waiting 0.00 days
# 211.82: STROKE arrival.
# Patient 169 gets a bed at 211.82 days  waiting 0.00 days
# 211.93: STROKE arrival.
# Patient 170 gets a bed at 211.93 days  waiting 0.00 days
# 212.35: COMPLEX NEURO arrival.
# Patient 50 gets a bed at 212.35 days  waiting 0.00 days
# 212.90: COMPLEX NEURO arrival.
# Patient 51 gets a bed at 212.90 days  waiting 0.00 days
# 213.38: STROKE arrival.
# Patient 171 gets a bed at 213.38 days  waiting 0.00 days
# 213.66: TIA arrival.
# Patient 17 gets a bed at 213.66 days  waiting 0.00 days
# 215.02: OTHER arrival.
# Patient 64 gets a bed at 215.02 days  waiting 0.00 days
# 215.57: STROKE arrival.
# Patient 172 gets a bed at 215.57 days  waiting 0.00 days
# 215.99: COMPLEX NEURO arrival.
# Patient 52 gets a bed at 215.99 days  waiting 0.00 days
# 216.02: OTHER arrival.
# Patient 65 gets a bed at 216.02 days  waiting 0.00 days
# 216.66: COMPLEX NEURO arrival.
# Patient 53 gets a bed at 216.66 days  waiting 0.00 days
# 216.94: COMPLEX NEURO arrival.
# Patient 54 gets a bed at 216.94 days  waiting 0.00 days
# 216.95: OTHER arrival.
# Patient 66 gets a bed at 216.95 days  waiting 0.00 days
# 216.99: STROKE arrival.
# Patient 173 gets a bed at 216.99 days  waiting 0.00 days
# 217.45: STROKE arrival.
# Patient 174 gets a bed at 217.45 days  waiting 0.00 days
# 218.83: OTHER arrival.
# Patient 67 gets a bed at 218.83 days  waiting 0.00 days
# 218.87: OTHER arrival.
# Patient 68 gets a bed at 218.87 days  waiting 0.00 days
# 219.48: COMPLEX NEURO arrival.
# Patient 55 gets a bed at 219.48 days  waiting 0.00 days
# 220.38: STROKE arrival.
# Patient 175 gets a bed at 220.38 days  waiting 0.00 days
# 221.30: STROKE arrival.
# Patient 176 gets a bed at 221.30 days  waiting 0.00 days
# 221.33: STROKE arrival.
# Patient 177 gets a bed at 221.33 days  waiting 0.00 days
# 221.44: STROKE arrival.
# Patient 178 gets a bed at 221.44 days  waiting 0.00 days
# 221.60: STROKE arrival.
# Patient 179 gets a bed at 221.60 days  waiting 0.00 days
# 221.86: COMPLEX NEURO arrival.
# Patient 56 gets a bed at 221.86 days  waiting 0.00 days
# 222.65: TIA arrival.
# Patient 18 gets a bed at 222.65 days  waiting 0.00 days
# 222.73: STROKE arrival.
# Patient 180 gets a bed at 222.73 days  waiting 0.00 days
# 223.10: COMPLEX NEURO arrival.
# Patient 57 gets a bed at 223.10 days  waiting 0.00 days
# 223.22: OTHER arrival.
# Patient 69 gets a bed at 223.22 days  waiting 0.00 days
# 223.44: STROKE arrival.
# Patient 181 gets a bed at 223.44 days  waiting 0.00 days
# 225.06: STROKE arrival.
# Patient 182 gets a bed at 225.06 days  waiting 0.00 days
# 226.11: STROKE arrival.
# Patient 183 gets a bed at 226.11 days  waiting 0.00 days
# 226.69: STROKE arrival.
# Patient 184 gets a bed at 226.69 days  waiting 0.00 days
# 228.02: STROKE arrival.
# Patient 185 gets a bed at 228.02 days  waiting 0.00 days
# 228.51: OTHER arrival.
# Patient 70 gets a bed at 228.51 days  waiting 0.00 days
# 228.59: STROKE arrival.
# Patient 186 gets a bed at 228.59 days  waiting 0.00 days
# 228.93: STROKE arrival.
# Patient 187 gets a bed at 228.93 days  waiting 0.00 days
# 229.05: STROKE arrival.
# Patient 188 gets a bed at 229.05 days  waiting 0.00 days
# 229.13: STROKE arrival.
# Patient 189 gets a bed at 229.13 days  waiting 0.00 days
# 229.17: TIA arrival.
# Patient 19 gets a bed at 229.17 days  waiting 0.00 days
# 229.34: OTHER arrival.
# Patient 71 gets a bed at 229.34 days  waiting 0.00 days
# 229.36: STROKE arrival.
# Patient 190 gets a bed at 229.36 days  waiting 0.00 days
# 229.92: OTHER arrival.
# Patient 72 gets a bed at 229.92 days  waiting 0.00 days
# 230.82: OTHER arrival.
# Patient 73 gets a bed at 230.82 days  waiting 0.00 days
# 231.03: OTHER arrival.
# Patient 74 gets a bed at 231.03 days  waiting 0.00 days
# 232.39: STROKE arrival.
# Patient 191 gets a bed at 232.39 days  waiting 0.00 days
# 233.28: COMPLEX NEURO arrival.
# Patient 58 gets a bed at 233.28 days  waiting 0.00 days
# 234.62: STROKE arrival.
# Patient 192 gets a bed at 234.62 days  waiting 0.00 days
# 234.82: OTHER arrival.
# Patient 75 gets a bed at 234.82 days  waiting 0.00 days
# 234.94: STROKE arrival.
# Patient 193 gets a bed at 234.94 days  waiting 0.00 days
# 235.39: STROKE arrival.
# Patient 194 gets a bed at 235.39 days  waiting 0.00 days
# 236.34: OTHER arrival.
# Patient 76 gets a bed at 236.34 days  waiting 0.00 days
# 236.67: STROKE arrival.
# Patient 195 gets a bed at 236.67 days  waiting 0.00 days
# 236.81: COMPLEX NEURO arrival.
# Patient 59 gets a bed at 236.81 days  waiting 0.00 days
# 237.89: OTHER arrival.
# Patient 77 gets a bed at 237.89 days  waiting 0.00 days
# 238.08: STROKE arrival.
# Patient 196 gets a bed at 238.08 days  waiting 0.00 days
# 238.14: COMPLEX NEURO arrival.
# Patient 60 gets a bed at 238.14 days  waiting 0.00 days
# 238.25: OTHER arrival.
# Patient 78 gets a bed at 238.25 days  waiting 0.00 days
# 238.28: STROKE arrival.
# Patient 197 gets a bed at 238.28 days  waiting 0.00 days
# 238.66: OTHER arrival.
# Patient 79 gets a bed at 238.66 days  waiting 0.00 days
# 238.86: STROKE arrival.
# Patient 198 gets a bed at 238.86 days  waiting 0.00 days
# 239.22: OTHER arrival.
# Patient 80 gets a bed at 239.22 days  waiting 0.00 days
# 239.55: STROKE arrival.
# Patient 199 gets a bed at 239.55 days  waiting 0.00 days
# 239.59: STROKE arrival.
# Patient 200 gets a bed at 239.59 days  waiting 0.00 days
# {'n_stroke': 200,
#  'n_tia': 19,
#  'n_complex_neuro': 60,
#  'n_other': 80,
#  'n_patients': 359}

# %%
# percentage of patients with stroke who are admitted to the stroke unit
stroke_percentage = results["n_stroke"] / results["n_patients"]
tia_percentage = results["n_tia"] / results["n_patients"]
complex_percentage = results["n_complex_neuro"] / results["n_patients"]
other_percentage = results["n_other"] / results["n_patients"]

print(f"% stroke: {stroke_percentage*100:.2f}%")
print(f"% tia : {tia_percentage*100:.2f}%")
print(f"% complex neuro: {complex_percentage*100:.2f}%")
print(f"% Others: {other_percentage*100:.2f}%")
# Out:
# % stroke: 55.71%
# % tia : 5.29%
# % complex neuro: 16.71%
# % Others: 22.28%

# %% [markdown]
# ## A hospital that only provides surgery for hip fractures

# %%
M = 1_000_000
experiment = Experiment(iat_stroke=M, iat_complex_neuro=M, iat_other=M)
results = single_run(experiment)
results
# Out:
# 7.47: TIA arrival.
# Patient 1 gets a bed at 7.47 days  waiting 0.00 days
# 11.02: TIA arrival.
# Patient 2 gets a bed at 11.02 days  waiting 0.00 days
# 14.41: TIA arrival.
# Patient 3 gets a bed at 14.41 days  waiting 0.00 days
# 19.33: TIA arrival.
# Patient 4 gets a bed at 19.33 days  waiting 0.00 days
# 45.26: TIA arrival.
# Patient 5 gets a bed at 45.26 days  waiting 0.00 days
# 63.50: TIA arrival.
# Patient 6 gets a bed at 63.50 days  waiting 0.00 days
# 72.33: TIA arrival.
# Patient 7 gets a bed at 72.33 days  waiting 0.00 days
# 111.08: TIA arrival.
# Patient 8 gets a bed at 111.08 days  waiting 0.00 days
# 116.54: TIA arrival.
# Patient 9 gets a bed at 116.54 days  waiting 0.00 days
# 142.47: TIA arrival.
# Patient 10 gets a bed at 142.47 days  waiting 0.00 days
# 165.64: TIA arrival.
# Patient 11 gets a bed at 165.64 days  waiting 0.00 days
# 182.45: TIA arrival.
# Patient 12 gets a bed at 182.45 days  waiting 0.00 days
# 185.34: TIA arrival.
# Patient 13 gets a bed at 185.34 days  waiting 0.00 days
# 210.21: TIA arrival.
# Patient 14 gets a bed at 210.21 days  waiting 0.00 days
# 210.91: TIA arrival.
# Patient 15 gets a bed at 210.91 days  waiting 0.00 days
# 211.40: TIA arrival.
# Patient 16 gets a bed at 211.40 days  waiting 0.00 days
# 213.66: TIA arrival.
# Patient 17 gets a bed at 213.66 days  waiting 0.00 days
# 222.65: TIA arrival.
# Patient 18 gets a bed at 222.65 days  waiting 0.00 days
# 229.17: TIA arrival.
# Patient 19 gets a bed at 229.17 days  waiting 0.00 days
# {'n_stroke': 0,
#  'n_tia': 19,
#  'n_complex_neuro': 0,
#  'n_other': 0,
#  'n_patients': 19}
