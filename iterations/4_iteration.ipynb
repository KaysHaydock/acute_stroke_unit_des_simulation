# %% [markdown]
# # Iteration 4: includes 4 types of patients , 4 types of LOS distributions and tracks the number of patients in each state at each time step.

# %% [markdown]
# ---

# %% [markdown]
# ## **. Patient Admission Sources**
# Patients enter the hospital through **two primary pathways**:
# - **New Admissions**: Direct hospital entry for Stroke, TIA, Complex Neurological, and Other Medical Cases.
#
#
# | Patient Type                     | Admissions (n) | Percentage (%) |
# |----------------------------------|---------------|--------------|
# | Stroke                           | 1,320         | 54%          |
# | Transient Ischemic Attack (TIA)  | 158           | 6%           |
# | Complex Neurological             | 456           | 19%          |
# | Other Medical Cases              | 510           | 21%          |
#
# **Patient admissions are distributed as follows**
#
# | Category                | Mean(Days) |
# |-------------------------|----------------------------|
# | Stroke                  | 1.2                        |
# | TIA (Transient Ischemic Attack) | 9.3                |
# | Complex Neurological    | 3.6                        |
# | Other                   | 3.2                        |

# %% [markdown]
# ## 1. Imports

# %%
import numpy as np
import itertools
import simpy
import os
import sys

# %%
# Add parent directory to path so we can import distribution.py
sys.path.append(os.path.abspath('..'))  # noqa: E402

from distribution import Exponential, Lognormal  # noqa: E402

# %% [markdown]
# ## 2. Constants

# %%
# default mean inter-arrival times(exp)
IAT_STROKE = 1.2
IAT_TIA = 9.3
IAT_COMPLEX_NEURO = 3.6
IAT_OTHER = 3.2

# Default Length of Stay (LOS) parameters
# (mean, stdev for Lognormal distribution
LOS_STROKE = (7.4, 8.6)
# LOS_STROKE_NESD = (7.4, 8.6)
# LOS_STROKE_ESD = (4.6, 4.8)
# LOS_STROKE_MORTALITY = (7.0, 8.7)
LOS_TIA = (1.8, 2.3)
LOS_COMPLEX_NEURO = (4.0, 5.0)
LOS_OTHER = (3.8, 5.2)

# sampling settings, 4 for arrivals, 4 for LOS
N_STREAMS = 8
DEFAULT_RND_SET = 0

# Boolean switch to simulation results as the model runs
TRACE = False

# run variables (units = hours)
RUN_LENGTH = 24 * 10

# %% [markdown]
# ## 2. Helper classes and functions

# %%
def trace(msg):
    """
    Turing printing of events on and off.

    Params:
    -------
    msg: str
        string to print to screen.
    """
    if TRACE:
        print(msg)

# %% [markdown]
# ## 3. Experiment class

# %%
class Experiment:
    """
    Encapsulates the concept of an experiment for
    the Acute Stroke Unit simulation.
    Manages parameters, PRNG streams, and results.
    """

    def __init__(
        self,
        random_number_set=0,
        n_streams=N_STREAMS,
        iat_stroke=IAT_STROKE,
        iat_tia=IAT_TIA,
        iat_complex_neuro=IAT_COMPLEX_NEURO,
        iat_other=IAT_OTHER,
        asu_beds=10,
        los_stroke=LOS_STROKE,
        los_tia=LOS_TIA,
        los_complex_neuro=LOS_COMPLEX_NEURO,
        los_other=LOS_OTHER,
    ):
        """
        Initialize default parameters.
        """
        # Sampling settings
        self.random_number_set = random_number_set
        self.n_streams = n_streams

        # Model parameters
        self.iat_stroke = iat_stroke
        self.iat_tia = iat_tia
        self.iat_complex_neuro = iat_complex_neuro
        self.iat_other = iat_other
        self.asu_beds = asu_beds

        # LOS Parameters
        self.los_stroke = los_stroke
        self.los_tia = los_tia
        self.los_complex_neuro = los_complex_neuro
        self.los_other = los_other

        # Initialize results storage
        self.init_results_variables()

        # Initialize sampling distributions
        self.init_sampling()

    def set_random_no_set(self, random_number_set):
        """
        Controls the random sampling.

        Parameters:
        ----------
        random_number_set: int
            Controls the set of pseudo-random
            numbers used by the distributions.
        """
        self.random_number_set = random_number_set
        self.init_sampling()

    def init_sampling(self):
        """
        Creates the distributions used by the model and initializes
        the random seeds of each.
        """
        # Produce n non-overlapping streams
        seed_sequence = np.random.SeedSequence(self.random_number_set)
        self.seeds = seed_sequence.spawn(self.n_streams)

        # Inter-arrival time distributions
        self.arrival_stroke = Exponential(
            self.iat_stroke, random_seed=self.seeds[0]
        )
        self.arrival_tia = Exponential(self.iat_tia, random_seed=self.seeds[1])
        self.arrival_complex_neuro = Exponential(
            self.iat_complex_neuro, random_seed=self.seeds[2]
        )
        self.arrival_other = Exponential(
            self.iat_other, random_seed=self.seeds[3]
        )

        # LOS distributions using stored parameters
        self.los_distributions = {
            "stroke": Lognormal(*self.los_stroke, random_seed=self.seeds[4]),
            "tia": Lognormal(*self.los_tia, random_seed=self.seeds[5]),
            "complex_neuro": Lognormal(
                *self.los_complex_neuro, random_seed=self.seeds[6]
            ),
            "other": Lognormal(*self.los_other, random_seed=self.seeds[7]),
        }

    def init_results_variables(self):
        """
        Initializes all the experiment variables used in results collection.
        """
        self.results = {}
        self.results["n_stroke"] = 0
        self.results["n_tia"] = 0
        self.results["n_complex_neuro"] = 0
        self.results["n_other"] = 0
        self.results["n_patients"] = 0
        self.results["n_stroke_discharged"] = 0
        self.results["n_tia_discharged"] = 0
        self.results["n_complex_neuro_discharged"] = 0
        self.results["n_other_discharged"] = 0
        self.results["n_discharged"] = 0

# %% [markdown]
# ## 3. Patient Class

# %%
class Patient:
    """
    Represents a patient in the system.
    """

    def __init__(self, patient_id, env, args, acute_stroke_unit, patient_type):
        self.patient_id = patient_id
        self.env = env
        self.args = args
        self.acute_stroke_unit = acute_stroke_unit  # Pass the ASU instance
        self.patient_type = patient_type

    def treatment(self):
        """
        Simulates patient treatment process.
        """
        arrival_time = self.env.now
        los_distribution = self.args.los_distributions[self.patient_type]

        # Arrival message
        trace(
            f"Patient {self.patient_id} ({self.patient_type.upper()}) \
            arrives at {self.env.now:.2f}."
        )

        # Request bed
        with self.acute_stroke_unit.beds.request() as request:
            yield request
            waiting_time = self.env.now - arrival_time
            los = los_distribution.sample()  # Sample LOS from distribution
            # tested los matched
            # print(los)

            # Bed assigned message
            trace(
                f"Patient {self.patient_id} ({self.patient_type.upper()}) "
                f" gets a bed at {self.env.now:.2f}."
                f" waiting time: {waiting_time:.2f} days."
            )

            # Simulate length of stay
            yield self.env.timeout(los)  # Patient stays in bed

            # Track patient discharge
            self.args.results[f"n_{self.patient_type}_discharged"] += 1
            self.args.results["n_discharged"] += 1

            # Leaving message
            trace(
                f"Patient {self.patient_id} ({self.patient_type.upper()}) \
                leaves at {self.env.now:.2f}."
            )
            trace(
                f"Patient {self.patient_id} ({self.patient_type.upper()}) \
                has a length of stay of {los:.2f} days."
            )

# %% [markdown]
# ### 4. Acute Stroke Unit Class

# %%
class AcuteStrokeUnit:
    """
    Models the Acute Stroke Unit (ASU) in the hospital.
    """

    def __init__(self, env, args):
        self.env = env
        self.args = args
        self.beds = simpy.Resource(env, capacity=args.asu_beds)

    def patient_arrivals(self, patient_type, arrival_distribution):
        """
        Generic arrival generator for patients.
        """
        for patient_count in itertools.count(start=1):
            inter_arrival_time = arrival_distribution.sample()
            yield self.env.timeout(inter_arrival_time)

            # Track patient count for each type
            self.args.results[f"n_{patient_type}"] += 1
            self.args.results["n_patients"] += 1
            trace(f"{self.env.now:.2f}: {patient_type.upper()} arrival.")

            # Create new patient and process their treatment
            new_patient = Patient(
                patient_count, self.env, self.args, self, patient_type
            )
            self.env.process(new_patient.treatment())

# %% [markdown]
# ## 4. A function per arrival source
#
# The first approach we will use is creating an arrival generator per source.  There will be some code redundancy, but it will a clear design for others to understand.

# %% [markdown]
# ## 5. Single run function

# %%
def single_run(experiment, rep=0, run_length=RUN_LENGTH):
    """
    Perform a single run of the model and return the results

    Parameters:
    -----------

    experiment: Experiment
        The experiment/parameters to use with model

    rep: int
        The replication number.

    run_length: float, optional (default=RUN_LENGTH)
        The run length of the model
    """

    # Reset results for each run
    experiment.init_results_variables()

    # Set the random number set for the run
    experiment.set_random_no_set(rep)

    # environment is (re)created inside single run
    env = simpy.Environment()
    asu = AcuteStrokeUnit(env, experiment)  # Create ASU instance

    # Create patient arrival processes for different types of patients
    env.process(asu.patient_arrivals("stroke", experiment.arrival_stroke))
    env.process(asu.patient_arrivals("tia", experiment.arrival_tia))
    env.process(
        asu.patient_arrivals("complex_neuro", experiment.arrival_complex_neuro)
    )
    env.process(asu.patient_arrivals("other", experiment.arrival_other))

    # run for warm-up + results collection period
    env.run(until=run_length)

    # Final summary after the simulation ends
    total_patients = sum(
        experiment.results[key]
        for key in experiment.results
        if key.startswith("n_")
    )
    trace(
        f"Final summary: There were a total of {total_patients} \
        patients in the system."
    )

    # return the count of the arrivals
    return experiment.results

# %%
TRACE = True
experiment = Experiment()
results = single_run(experiment)
results
# Out:
# 3.95: STROKE arrival.
# Patient 1 (STROKE)             arrives at 3.95.
# Patient 1 (STROKE)  gets a bed at 3.95. waiting time: 0.00 days.
# 4.64: OTHER arrival.
# Patient 1 (OTHER)             arrives at 4.64.
# Patient 1 (OTHER)  gets a bed at 4.64. waiting time: 0.00 days.
# 4.87: STROKE arrival.
# Patient 2 (STROKE)             arrives at 4.87.
# Patient 2 (STROKE)  gets a bed at 4.87. waiting time: 0.00 days.
# 4.95: OTHER arrival.
# Patient 2 (OTHER)             arrives at 4.95.
# Patient 2 (OTHER)  gets a bed at 4.95. waiting time: 0.00 days.
# 5.51: COMPLEX_NEURO arrival.
# Patient 1 (COMPLEX_NEURO)             arrives at 5.51.
# Patient 1 (COMPLEX_NEURO)  gets a bed at 5.51. waiting time: 0.00 days.
# 5.92: COMPLEX_NEURO arrival.
# Patient 2 (COMPLEX_NEURO)             arrives at 5.92.
# Patient 2 (COMPLEX_NEURO)  gets a bed at 5.92. waiting time: 0.00 days.
# Patient 1 (OTHER)                 leaves at 6.14.
# Patient 1 (OTHER)                 has a length of stay of 1.50 days.
# Patient 2 (STROKE)                 leaves at 6.19.
# Patient 2 (STROKE)                 has a length of stay of 1.32 days.
# 6.37: STROKE arrival.
# Patient 3 (STROKE)             arrives at 6.37.
# Patient 3 (STROKE)  gets a bed at 6.37. waiting time: 0.00 days.
# 6.64: STROKE arrival.
# Patient 4 (STROKE)             arrives at 6.64.
# Patient 4 (STROKE)  gets a bed at 6.64. waiting time: 0.00 days.
# 6.91: STROKE arrival.
# Patient 5 (STROKE)             arrives at 6.91.
# Patient 5 (STROKE)  gets a bed at 6.91. waiting time: 0.00 days.
# Patient 2 (OTHER)                 leaves at 7.03.
# Patient 2 (OTHER)                 has a length of stay of 2.08 days.
# 7.47: TIA arrival.
# Patient 1 (TIA)             arrives at 7.47.
# Patient 1 (TIA)  gets a bed at 7.47. waiting time: 0.00 days.
# Patient 4 (STROKE)                 leaves at 7.49.
# Patient 4 (STROKE)                 has a length of stay of 0.85 days.
# Patient 1 (TIA)                 leaves at 8.52.
# Patient 1 (TIA)                 has a length of stay of 1.06 days.
# Patient 2 (COMPLEX_NEURO)                 leaves at 8.64.
# Patient 2 (COMPLEX_NEURO)                 has a length of stay of 2.72 days.
# 9.07: STROKE arrival.
# Patient 6 (STROKE)             arrives at 9.07.
# Patient 6 (STROKE)  gets a bed at 9.07. waiting time: 0.00 days.
# 9.12: OTHER arrival.
# Patient 3 (OTHER)             arrives at 9.12.
# Patient 3 (OTHER)  gets a bed at 9.12. waiting time: 0.00 days.
# 9.15: STROKE arrival.
# Patient 7 (STROKE)             arrives at 9.15.
# Patient 7 (STROKE)  gets a bed at 9.15. waiting time: 0.00 days.
# 9.34: OTHER arrival.
# Patient 4 (OTHER)             arrives at 9.34.
# Patient 4 (OTHER)  gets a bed at 9.34. waiting time: 0.00 days.
# Patient 3 (OTHER)                 leaves at 9.55.
# Patient 3 (OTHER)                 has a length of stay of 0.43 days.
# Patient 1 (STROKE)                 leaves at 9.68.
# Patient 1 (STROKE)                 has a length of stay of 5.72 days.
# 9.83: OTHER arrival.
# Patient 5 (OTHER)             arrives at 9.83.
# Patient 5 (OTHER)  gets a bed at 9.83. waiting time: 0.00 days.
# 10.16: COMPLEX_NEURO arrival.
# Patient 3 (COMPLEX_NEURO)             arrives at 10.16.
# Patient 3 (COMPLEX_NEURO)  gets a bed at 10.16. waiting time: 0.00 days.
# 10.23: STROKE arrival.
# Patient 8 (STROKE)             arrives at 10.23.
# Patient 8 (STROKE)  gets a bed at 10.23. waiting time: 0.00 days.
# 10.44: OTHER arrival.
# Patient 6 (OTHER)             arrives at 10.44.
# Patient 6 (OTHER)  gets a bed at 10.44. waiting time: 0.00 days.
# 10.58: STROKE arrival.
# Patient 9 (STROKE)             arrives at 10.58.
# Patient 6 (OTHER)                 leaves at 10.66.
# Patient 6 (OTHER)                 has a length of stay of 0.22 days.
# Patient 9 (STROKE)  gets a bed at 10.66. waiting time: 0.08 days.
# Patient 4 (OTHER)                 leaves at 10.98.
# Patient 4 (OTHER)                 has a length of stay of 1.63 days.
# 11.02: TIA arrival.
# Patient 2 (TIA)             arrives at 11.02.
# Patient 2 (TIA)  gets a bed at 11.02. waiting time: 0.00 days.
# Patient 2 (TIA)                 leaves at 11.33.
# Patient 2 (TIA)                 has a length of stay of 0.31 days.
# Patient 6 (STROKE)                 leaves at 11.60.
# Patient 6 (STROKE)                 has a length of stay of 2.54 days.
# Patient 3 (COMPLEX_NEURO)                 leaves at 12.79.
# Patient 3 (COMPLEX_NEURO)                 has a length of stay of 2.63 days.
# Patient 5 (OTHER)                 leaves at 12.81.
# Patient 5 (OTHER)                 has a length of stay of 2.98 days.
# 13.34: STROKE arrival.
# Patient 10 (STROKE)             arrives at 13.34.
# Patient 10 (STROKE)  gets a bed at 13.34. waiting time: 0.00 days.
# 14.41: TIA arrival.
# Patient 3 (TIA)             arrives at 14.41.
# Patient 3 (TIA)  gets a bed at 14.41. waiting time: 0.00 days.
# Patient 3 (TIA)                 leaves at 14.78.
# Patient 3 (TIA)                 has a length of stay of 0.37 days.
# Patient 3 (STROKE)                 leaves at 15.35.
# Patient 3 (STROKE)                 has a length of stay of 8.98 days.
# 15.57: STROKE arrival.
# Patient 11 (STROKE)             arrives at 15.57.
# Patient 11 (STROKE)  gets a bed at 15.57. waiting time: 0.00 days.
# 15.59: STROKE arrival.
# Patient 12 (STROKE)             arrives at 15.59.
# Patient 12 (STROKE)  gets a bed at 15.59. waiting time: 0.00 days.
# Patient 5 (STROKE)                 leaves at 15.65.
# Patient 5 (STROKE)                 has a length of stay of 8.74 days.
# Patient 10 (STROKE)                 leaves at 17.74.
# Patient 10 (STROKE)                 has a length of stay of 4.40 days.
# 17.95: COMPLEX_NEURO arrival.
# Patient 4 (COMPLEX_NEURO)             arrives at 17.95.
# Patient 4 (COMPLEX_NEURO)  gets a bed at 17.95. waiting time: 0.00 days.
# Patient 4 (COMPLEX_NEURO)                 leaves at 18.43.
# Patient 4 (COMPLEX_NEURO)                 has a length of stay of 0.48 days.
# 19.17: OTHER arrival.
# Patient 7 (OTHER)             arrives at 19.17.
# Patient 7 (OTHER)  gets a bed at 19.17. waiting time: 0.00 days.
# 19.33: TIA arrival.
# Patient 4 (TIA)             arrives at 19.33.
# Patient 4 (TIA)  gets a bed at 19.33. waiting time: 0.00 days.
# 19.34: COMPLEX_NEURO arrival.
# Patient 5 (COMPLEX_NEURO)             arrives at 19.34.
# Patient 5 (COMPLEX_NEURO)  gets a bed at 19.34. waiting time: 0.00 days.
# Patient 8 (STROKE)                 leaves at 20.06.
# Patient 8 (STROKE)                 has a length of stay of 9.83 days.
# Patient 4 (TIA)                 leaves at 20.48.
# Patient 4 (TIA)                 has a length of stay of 1.15 days.
# 21.13: COMPLEX_NEURO arrival.
# Patient 6 (COMPLEX_NEURO)             arrives at 21.13.
# Patient 6 (COMPLEX_NEURO)  gets a bed at 21.13. waiting time: 0.00 days.
# Patient 11 (STROKE)                 leaves at 21.72.
# Patient 11 (STROKE)                 has a length of stay of 6.15 days.
# Patient 9 (STROKE)                 leaves at 22.03.
# Patient 9 (STROKE)                 has a length of stay of 11.37 days.
# 22.30: STROKE arrival.
# Patient 13 (STROKE)             arrives at 22.30.
# Patient 13 (STROKE)  gets a bed at 22.30. waiting time: 0.00 days.
# 22.36: COMPLEX_NEURO arrival.
# Patient 7 (COMPLEX_NEURO)             arrives at 22.36.
# Patient 7 (COMPLEX_NEURO)  gets a bed at 22.36. waiting time: 0.00 days.
# Patient 7 (OTHER)                 leaves at 22.55.
# Patient 7 (OTHER)                 has a length of stay of 3.38 days.
# 23.26: STROKE arrival.
# Patient 14 (STROKE)             arrives at 23.26.
# Patient 14 (STROKE)  gets a bed at 23.26. waiting time: 0.00 days.
# 23.68: STROKE arrival.
# Patient 15 (STROKE)             arrives at 23.68.
# Patient 15 (STROKE)  gets a bed at 23.68. waiting time: 0.00 days.
# Patient 13 (STROKE)                 leaves at 25.25.
# Patient 13 (STROKE)                 has a length of stay of 2.94 days.
# Patient 7 (COMPLEX_NEURO)                 leaves at 25.57.
# Patient 7 (COMPLEX_NEURO)                 has a length of stay of 3.22 days.
# 25.78: COMPLEX_NEURO arrival.
# Patient 8 (COMPLEX_NEURO)             arrives at 25.78.
# Patient 8 (COMPLEX_NEURO)  gets a bed at 25.78. waiting time: 0.00 days.
# 26.04: STROKE arrival.
# Patient 16 (STROKE)             arrives at 26.04.
# Patient 16 (STROKE)  gets a bed at 26.04. waiting time: 0.00 days.
# 26.82: OTHER arrival.
# Patient 8 (OTHER)             arrives at 26.82.
# Patient 8 (OTHER)  gets a bed at 26.82. waiting time: 0.00 days.
# 26.93: STROKE arrival.
# Patient 17 (STROKE)             arrives at 26.93.
# 26.94: STROKE arrival.
# Patient 18 (STROKE)             arrives at 26.94.
# 26.99: OTHER arrival.
# Patient 9 (OTHER)             arrives at 26.99.
# Patient 16 (STROKE)                 leaves at 27.85.
# Patient 16 (STROKE)                 has a length of stay of 1.81 days.
# Patient 17 (STROKE)  gets a bed at 27.85. waiting time: 0.92 days.
# 27.94: STROKE arrival.
# Patient 19 (STROKE)             arrives at 27.94.
# 28.68: STROKE arrival.
# Patient 20 (STROKE)             arrives at 28.68.
# 29.00: COMPLEX_NEURO arrival.
# Patient 9 (COMPLEX_NEURO)             arrives at 29.00.
# 29.41: STROKE arrival.
# Patient 21 (STROKE)             arrives at 29.41.
# Patient 15 (STROKE)                 leaves at 29.56.
# Patient 15 (STROKE)                 has a length of stay of 5.88 days.
# Patient 18 (STROKE)  gets a bed at 29.56. waiting time: 2.61 days.
# Patient 12 (STROKE)                 leaves at 29.82.
# Patient 12 (STROKE)                 has a length of stay of 14.23 days.
# Patient 9 (OTHER)  gets a bed at 29.82. waiting time: 2.83 days.
# 29.88: COMPLEX_NEURO arrival.
# Patient 10 (COMPLEX_NEURO)             arrives at 29.88.
# 29.91: COMPLEX_NEURO arrival.
# Patient 11 (COMPLEX_NEURO)             arrives at 29.91.
# 30.20: OTHER arrival.
# Patient 10 (OTHER)             arrives at 30.20.
# 31.43: COMPLEX_NEURO arrival.
# Patient 12 (COMPLEX_NEURO)             arrives at 31.43.
# 32.81: STROKE arrival.
# Patient 22 (STROKE)             arrives at 32.81.
# 33.10: STROKE arrival.
# Patient 23 (STROKE)             arrives at 33.10.
# Patient 8 (OTHER)                 leaves at 33.14.
# Patient 8 (OTHER)                 has a length of stay of 6.32 days.
# Patient 19 (STROKE)  gets a bed at 33.14. waiting time: 5.20 days.
# Patient 9 (OTHER)                 leaves at 34.06.
# Patient 9 (OTHER)                 has a length of stay of 4.24 days.
# Patient 20 (STROKE)  gets a bed at 34.06. waiting time: 5.38 days.
# 34.53: COMPLEX_NEURO arrival.
# Patient 13 (COMPLEX_NEURO)             arrives at 34.53.
# Patient 19 (STROKE)                 leaves at 35.05.
# Patient 19 (STROKE)                 has a length of stay of 1.91 days.
# Patient 9 (COMPLEX_NEURO)  gets a bed at 35.05. waiting time: 6.04 days.
# Patient 5 (COMPLEX_NEURO)                 leaves at 35.05.
# Patient 5 (COMPLEX_NEURO)                 has a length of stay of 15.72 days.
# Patient 21 (STROKE)  gets a bed at 35.05. waiting time: 5.65 days.
# Patient 18 (STROKE)                 leaves at 35.21.
# Patient 18 (STROKE)                 has a length of stay of 5.65 days.
# Patient 10 (COMPLEX_NEURO)  gets a bed at 35.21. waiting time: 5.32 days.
# 36.10: STROKE arrival.
# Patient 24 (STROKE)             arrives at 36.10.
# 36.43: COMPLEX_NEURO arrival.
# Patient 14 (COMPLEX_NEURO)             arrives at 36.43.
# 36.49: STROKE arrival.
# Patient 25 (STROKE)             arrives at 36.49.
# 37.46: OTHER arrival.
# Patient 11 (OTHER)             arrives at 37.46.
# 38.03: OTHER arrival.
# Patient 12 (OTHER)             arrives at 38.03.
# 38.35: STROKE arrival.
# Patient 26 (STROKE)             arrives at 38.35.
# Patient 1 (COMPLEX_NEURO)                 leaves at 38.86.
# Patient 1 (COMPLEX_NEURO)                 has a length of stay of 33.35 days.
# Patient 11 (COMPLEX_NEURO)  gets a bed at 38.86. waiting time: 8.95 days.
# Patient 10 (COMPLEX_NEURO)                 leaves at 39.09.
# Patient 10 (COMPLEX_NEURO)                 has a length of stay of 3.88 days.
# Patient 10 (OTHER)  gets a bed at 39.09. waiting time: 8.89 days.
# Patient 20 (STROKE)                 leaves at 39.13.
# Patient 20 (STROKE)                 has a length of stay of 5.07 days.
# Patient 12 (COMPLEX_NEURO)  gets a bed at 39.13. waiting time: 7.70 days.
# 39.62: STROKE arrival.
# Patient 27 (STROKE)             arrives at 39.62.
# Patient 10 (OTHER)                 leaves at 39.64.
# Patient 10 (OTHER)                 has a length of stay of 0.56 days.
# Patient 22 (STROKE)  gets a bed at 39.64. waiting time: 6.83 days.
# 40.09: STROKE arrival.
# Patient 28 (STROKE)             arrives at 40.09.
# 40.22: OTHER arrival.
# Patient 13 (OTHER)             arrives at 40.22.
# 40.90: STROKE arrival.
# Patient 29 (STROKE)             arrives at 40.90.
# 41.23: OTHER arrival.
# Patient 14 (OTHER)             arrives at 41.23.
# Patient 11 (COMPLEX_NEURO)                 leaves at 41.47.
# Patient 11 (COMPLEX_NEURO)                 has a length of stay of 2.61 days.
# Patient 23 (STROKE)  gets a bed at 41.47. waiting time: 8.37 days.
# Patient 9 (COMPLEX_NEURO)                 leaves at 41.63.
# Patient 9 (COMPLEX_NEURO)                 has a length of stay of 6.59 days.
# Patient 13 (COMPLEX_NEURO)  gets a bed at 41.63. waiting time: 7.10 days.
# 41.76: COMPLEX_NEURO arrival.
# Patient 15 (COMPLEX_NEURO)             arrives at 41.76.
# Patient 13 (COMPLEX_NEURO)                 leaves at 42.14.
# Patient 13 (COMPLEX_NEURO)                 has a length of stay of 0.51 days.
# Patient 24 (STROKE)  gets a bed at 42.14. waiting time: 6.04 days.
# Patient 22 (STROKE)                 leaves at 42.19.
# Patient 22 (STROKE)                 has a length of stay of 2.55 days.
# Patient 14 (COMPLEX_NEURO)  gets a bed at 42.19. waiting time: 5.76 days.
# 42.78: COMPLEX_NEURO arrival.
# Patient 16 (COMPLEX_NEURO)             arrives at 42.78.
# 43.24: STROKE arrival.
# Patient 30 (STROKE)             arrives at 43.24.
# Patient 14 (COMPLEX_NEURO)                 leaves at 43.74.
# Patient 14 (COMPLEX_NEURO)                 has a length of stay of 1.55 days.
# Patient 25 (STROKE)  gets a bed at 43.74. waiting time: 7.25 days.
# Patient 17 (STROKE)                 leaves at 44.16.
# Patient 17 (STROKE)                 has a length of stay of 16.31 days.
# Patient 11 (OTHER)  gets a bed at 44.16. waiting time: 6.71 days.
# Patient 24 (STROKE)                 leaves at 44.45.
# Patient 24 (STROKE)                 has a length of stay of 2.31 days.
# Patient 12 (OTHER)  gets a bed at 44.45. waiting time: 6.42 days.
# Patient 23 (STROKE)                 leaves at 45.03.
# Patient 23 (STROKE)                 has a length of stay of 3.56 days.
# Patient 26 (STROKE)  gets a bed at 45.03. waiting time: 6.68 days.
# 45.26: TIA arrival.
# Patient 5 (TIA)             arrives at 45.26.
# Patient 25 (STROKE)                 leaves at 45.27.
# Patient 25 (STROKE)                 has a length of stay of 1.53 days.
# Patient 27 (STROKE)  gets a bed at 45.27. waiting time: 5.66 days.
# Patient 8 (COMPLEX_NEURO)                 leaves at 45.33.
# Patient 8 (COMPLEX_NEURO)                 has a length of stay of 19.55 days.
# Patient 28 (STROKE)  gets a bed at 45.33. waiting time: 5.24 days.
# 46.10: STROKE arrival.
# Patient 31 (STROKE)             arrives at 46.10.
# 46.29: OTHER arrival.
# Patient 15 (OTHER)             arrives at 46.29.
# 46.63: OTHER arrival.
# Patient 16 (OTHER)             arrives at 46.63.
# 47.10: STROKE arrival.
# Patient 32 (STROKE)             arrives at 47.10.
# Patient 21 (STROKE)                 leaves at 47.34.
# Patient 21 (STROKE)                 has a length of stay of 12.29 days.
# Patient 13 (OTHER)  gets a bed at 47.34. waiting time: 7.12 days.
# Patient 7 (STROKE)                 leaves at 47.88.
# Patient 7 (STROKE)                 has a length of stay of 38.73 days.
# Patient 29 (STROKE)  gets a bed at 47.88. waiting time: 6.97 days.
# Patient 12 (OTHER)                 leaves at 48.05.
# Patient 12 (OTHER)                 has a length of stay of 3.60 days.
# Patient 14 (OTHER)  gets a bed at 48.05. waiting time: 6.82 days.
# Patient 12 (COMPLEX_NEURO)                 leaves at 48.50.
# Patient 12 (COMPLEX_NEURO)                 has a length of stay of 9.36 days.
# Patient 15 (COMPLEX_NEURO)  gets a bed at 48.50. waiting time: 6.73 days.
# Patient 11 (OTHER)                 leaves at 48.70.
# Patient 11 (OTHER)                 has a length of stay of 4.54 days.
# Patient 16 (COMPLEX_NEURO)  gets a bed at 48.70. waiting time: 5.92 days.
# 48.92: COMPLEX_NEURO arrival.
# Patient 17 (COMPLEX_NEURO)             arrives at 48.92.
# Patient 6 (COMPLEX_NEURO)                 leaves at 48.99.
# Patient 6 (COMPLEX_NEURO)                 has a length of stay of 27.86 days.
# Patient 30 (STROKE)  gets a bed at 48.99. waiting time: 5.75 days.
# Patient 13 (OTHER)                 leaves at 49.20.
# Patient 13 (OTHER)                 has a length of stay of 1.85 days.
# Patient 5 (TIA)  gets a bed at 49.20. waiting time: 3.93 days.
# Patient 29 (STROKE)                 leaves at 49.38.
# Patient 29 (STROKE)                 has a length of stay of 1.50 days.
# Patient 31 (STROKE)  gets a bed at 49.38. waiting time: 3.28 days.
# 49.60: STROKE arrival.
# Patient 33 (STROKE)             arrives at 49.60.
# Patient 14 (OTHER)                 leaves at 49.72.
# Patient 14 (OTHER)                 has a length of stay of 1.67 days.
# Patient 15 (OTHER)  gets a bed at 49.72. waiting time: 3.43 days.
# Patient 15 (COMPLEX_NEURO)                 leaves at 49.92.
# Patient 15 (COMPLEX_NEURO)                 has a length of stay of 1.42 days.
# Patient 16 (OTHER)  gets a bed at 49.92. waiting time: 3.28 days.
# 50.43: STROKE arrival.
# Patient 34 (STROKE)             arrives at 50.43.
# Patient 16 (OTHER)                 leaves at 50.56.
# Patient 16 (OTHER)                 has a length of stay of 0.65 days.
# Patient 32 (STROKE)  gets a bed at 50.56. waiting time: 3.47 days.
# Patient 16 (COMPLEX_NEURO)                 leaves at 50.59.
# Patient 16 (COMPLEX_NEURO)                 has a length of stay of 1.89 days.
# Patient 17 (COMPLEX_NEURO)  gets a bed at 50.59. waiting time: 1.68 days.
# 50.99: STROKE arrival.
# Patient 35 (STROKE)             arrives at 50.99.
# 51.22: OTHER arrival.
# Patient 17 (OTHER)             arrives at 51.22.
# Patient 17 (COMPLEX_NEURO)                 leaves at 51.48.
# Patient 17 (COMPLEX_NEURO)                 has a length of stay of 0.88 days.
# Patient 33 (STROKE)  gets a bed at 51.48. waiting time: 1.88 days.
# 52.18: COMPLEX_NEURO arrival.
# Patient 18 (COMPLEX_NEURO)             arrives at 52.18.
# Patient 31 (STROKE)                 leaves at 52.36.
# Patient 31 (STROKE)                 has a length of stay of 2.98 days.
# Patient 34 (STROKE)  gets a bed at 52.36. waiting time: 1.93 days.
# 52.44: STROKE arrival.
# Patient 36 (STROKE)             arrives at 52.44.
# 52.54: STROKE arrival.
# Patient 37 (STROKE)             arrives at 52.54.
# Patient 15 (OTHER)                 leaves at 52.61.
# Patient 15 (OTHER)                 has a length of stay of 2.89 days.
# Patient 35 (STROKE)  gets a bed at 52.61. waiting time: 1.62 days.
# Patient 32 (STROKE)                 leaves at 52.70.
# Patient 32 (STROKE)                 has a length of stay of 2.14 days.
# Patient 17 (OTHER)  gets a bed at 52.70. waiting time: 1.48 days.
# 52.95: STROKE arrival.
# Patient 38 (STROKE)             arrives at 52.95.
# Patient 27 (STROKE)                 leaves at 53.18.
# Patient 27 (STROKE)                 has a length of stay of 7.90 days.
# Patient 18 (COMPLEX_NEURO)  gets a bed at 53.18. waiting time: 1.00 days.
# 53.21: OTHER arrival.
# Patient 18 (OTHER)             arrives at 53.21.
# Patient 5 (TIA)                 leaves at 53.43.
# Patient 5 (TIA)                 has a length of stay of 4.23 days.
# Patient 36 (STROKE)  gets a bed at 53.43. waiting time: 0.99 days.
# Patient 26 (STROKE)                 leaves at 53.45.
# Patient 26 (STROKE)                 has a length of stay of 8.42 days.
# Patient 37 (STROKE)  gets a bed at 53.45. waiting time: 0.91 days.
# Patient 33 (STROKE)                 leaves at 53.54.
# Patient 33 (STROKE)                 has a length of stay of 2.07 days.
# Patient 38 (STROKE)  gets a bed at 53.54. waiting time: 0.60 days.
# Patient 34 (STROKE)                 leaves at 53.91.
# Patient 34 (STROKE)                 has a length of stay of 1.55 days.
# Patient 18 (OTHER)  gets a bed at 53.91. waiting time: 0.70 days.
# 54.15: STROKE arrival.
# Patient 39 (STROKE)             arrives at 54.15.
# 54.43: STROKE arrival.
# Patient 40 (STROKE)             arrives at 54.43.
# Patient 17 (OTHER)                 leaves at 54.73.
# Patient 17 (OTHER)                 has a length of stay of 2.03 days.
# Patient 39 (STROKE)  gets a bed at 54.73. waiting time: 0.58 days.
# Patient 18 (OTHER)                 leaves at 55.20.
# Patient 18 (OTHER)                 has a length of stay of 1.29 days.
# Patient 40 (STROKE)  gets a bed at 55.20. waiting time: 0.77 days.
# 55.87: STROKE arrival.
# Patient 41 (STROKE)             arrives at 55.87.
# Patient 14 (STROKE)                 leaves at 56.20.
# Patient 14 (STROKE)                 has a length of stay of 32.94 days.
# Patient 41 (STROKE)  gets a bed at 56.20. waiting time: 0.33 days.
# 56.72: STROKE arrival.
# Patient 42 (STROKE)             arrives at 56.72.
# Patient 18 (COMPLEX_NEURO)                 leaves at 58.26.
# Patient 18 (COMPLEX_NEURO)                 has a length of stay of 5.08 days.
# Patient 42 (STROKE)  gets a bed at 58.26. waiting time: 1.54 days.
# Patient 37 (STROKE)                 leaves at 59.03.
# Patient 37 (STROKE)                 has a length of stay of 5.58 days.
# 59.60: OTHER arrival.
# Patient 19 (OTHER)             arrives at 59.60.
# Patient 19 (OTHER)  gets a bed at 59.60. waiting time: 0.00 days.
# Patient 30 (STROKE)                 leaves at 59.61.
# Patient 30 (STROKE)                 has a length of stay of 10.62 days.
# Patient 28 (STROKE)                 leaves at 59.97.
# Patient 28 (STROKE)                 has a length of stay of 14.64 days.
# Patient 41 (STROKE)                 leaves at 60.24.
# Patient 41 (STROKE)                 has a length of stay of 4.04 days.
# 60.46: OTHER arrival.
# Patient 20 (OTHER)             arrives at 60.46.
# Patient 20 (OTHER)  gets a bed at 60.46. waiting time: 0.00 days.
# 61.07: OTHER arrival.
# Patient 21 (OTHER)             arrives at 61.07.
# Patient 21 (OTHER)  gets a bed at 61.07. waiting time: 0.00 days.
# Patient 19 (OTHER)                 leaves at 61.20.
# Patient 19 (OTHER)                 has a length of stay of 1.60 days.
# Patient 39 (STROKE)                 leaves at 61.72.
# Patient 39 (STROKE)                 has a length of stay of 6.99 days.
# 61.79: STROKE arrival.
# Patient 43 (STROKE)             arrives at 61.79.
# Patient 43 (STROKE)  gets a bed at 61.79. waiting time: 0.00 days.
# 61.83: STROKE arrival.
# Patient 44 (STROKE)             arrives at 61.83.
# Patient 44 (STROKE)  gets a bed at 61.83. waiting time: 0.00 days.
# 62.01: OTHER arrival.
# Patient 22 (OTHER)             arrives at 62.01.
# Patient 22 (OTHER)  gets a bed at 62.01. waiting time: 0.00 days.
# Patient 21 (OTHER)                 leaves at 62.31.
# Patient 21 (OTHER)                 has a length of stay of 1.24 days.
# Patient 43 (STROKE)                 leaves at 62.88.
# Patient 43 (STROKE)                 has a length of stay of 1.10 days.
# 63.50: TIA arrival.
# Patient 6 (TIA)             arrives at 63.50.
# Patient 6 (TIA)  gets a bed at 63.50. waiting time: 0.00 days.
# Patient 20 (OTHER)                 leaves at 63.60.
# Patient 20 (OTHER)                 has a length of stay of 3.14 days.
# Patient 6 (TIA)                 leaves at 64.35.
# Patient 6 (TIA)                 has a length of stay of 0.85 days.
# 64.45: OTHER arrival.
# Patient 23 (OTHER)             arrives at 64.45.
# Patient 23 (OTHER)  gets a bed at 64.45. waiting time: 0.00 days.
# 64.90: OTHER arrival.
# Patient 24 (OTHER)             arrives at 64.90.
# Patient 24 (OTHER)  gets a bed at 64.90. waiting time: 0.00 days.
# 65.49: STROKE arrival.
# Patient 45 (STROKE)             arrives at 65.49.
# Patient 45 (STROKE)  gets a bed at 65.49. waiting time: 0.00 days.
# 65.75: STROKE arrival.
# Patient 46 (STROKE)             arrives at 65.75.
# 65.84: STROKE arrival.
# Patient 47 (STROKE)             arrives at 65.84.
# 66.95: STROKE arrival.
# Patient 48 (STROKE)             arrives at 66.95.
# Patient 22 (OTHER)                 leaves at 66.99.
# Patient 22 (OTHER)                 has a length of stay of 4.98 days.
# Patient 46 (STROKE)  gets a bed at 66.99. waiting time: 1.24 days.
# Patient 24 (OTHER)                 leaves at 67.01.
# Patient 24 (OTHER)                 has a length of stay of 2.11 days.
# Patient 47 (STROKE)  gets a bed at 67.01. waiting time: 1.17 days.
# 67.95: COMPLEX_NEURO arrival.
# Patient 19 (COMPLEX_NEURO)             arrives at 67.95.
# Patient 44 (STROKE)                 leaves at 68.04.
# Patient 44 (STROKE)                 has a length of stay of 6.21 days.
# Patient 48 (STROKE)  gets a bed at 68.04. waiting time: 1.09 days.
# 68.11: OTHER arrival.
# Patient 25 (OTHER)             arrives at 68.11.
# Patient 47 (STROKE)                 leaves at 68.34.
# Patient 47 (STROKE)                 has a length of stay of 1.33 days.
# Patient 19 (COMPLEX_NEURO)  gets a bed at 68.34. waiting time: 0.39 days.
# Patient 23 (OTHER)                 leaves at 68.39.
# Patient 23 (OTHER)                 has a length of stay of 3.94 days.
# Patient 25 (OTHER)  gets a bed at 68.39. waiting time: 0.28 days.
# Patient 40 (STROKE)                 leaves at 68.49.
# Patient 40 (STROKE)                 has a length of stay of 13.28 days.
# 68.64: COMPLEX_NEURO arrival.
# Patient 20 (COMPLEX_NEURO)             arrives at 68.64.
# Patient 20 (COMPLEX_NEURO)  gets a bed at 68.64. waiting time: 0.00 days.
# Patient 42 (STROKE)                 leaves at 68.93.
# Patient 42 (STROKE)                 has a length of stay of 10.67 days.
# 69.42: STROKE arrival.
# Patient 49 (STROKE)             arrives at 69.42.
# Patient 49 (STROKE)  gets a bed at 69.42. waiting time: 0.00 days.
# Patient 25 (OTHER)                 leaves at 69.57.
# Patient 25 (OTHER)                 has a length of stay of 1.18 days.
# Patient 19 (COMPLEX_NEURO)                 leaves at 69.61.
# Patient 19 (COMPLEX_NEURO)                 has a length of stay of 1.27 days.
# 69.69: COMPLEX_NEURO arrival.
# Patient 21 (COMPLEX_NEURO)             arrives at 69.69.
# Patient 21 (COMPLEX_NEURO)  gets a bed at 69.69. waiting time: 0.00 days.
# 69.80: COMPLEX_NEURO arrival.
# Patient 22 (COMPLEX_NEURO)             arrives at 69.80.
# Patient 22 (COMPLEX_NEURO)  gets a bed at 69.80. waiting time: 0.00 days.
# Patient 45 (STROKE)                 leaves at 69.81.
# Patient 45 (STROKE)                 has a length of stay of 4.32 days.
# Patient 48 (STROKE)                 leaves at 69.85.
# Patient 48 (STROKE)                 has a length of stay of 1.81 days.
# 70.28: STROKE arrival.
# Patient 50 (STROKE)             arrives at 70.28.
# Patient 50 (STROKE)  gets a bed at 70.28. waiting time: 0.00 days.
# 70.61: STROKE arrival.
# Patient 51 (STROKE)             arrives at 70.61.
# Patient 51 (STROKE)  gets a bed at 70.61. waiting time: 0.00 days.
# Patient 20 (COMPLEX_NEURO)                 leaves at 70.94.
# Patient 20 (COMPLEX_NEURO)                 has a length of stay of 2.30 days.
# Patient 22 (COMPLEX_NEURO)                 leaves at 71.24.
# Patient 22 (COMPLEX_NEURO)                 has a length of stay of 1.45 days.
# Patient 36 (STROKE)                 leaves at 71.26.
# Patient 36 (STROKE)                 has a length of stay of 17.83 days.
# 71.27: STROKE arrival.
# Patient 52 (STROKE)             arrives at 71.27.
# Patient 52 (STROKE)  gets a bed at 71.27. waiting time: 0.00 days.
# Patient 38 (STROKE)                 leaves at 71.39.
# Patient 38 (STROKE)                 has a length of stay of 17.85 days.
# 71.56: STROKE arrival.
# Patient 53 (STROKE)             arrives at 71.56.
# Patient 53 (STROKE)  gets a bed at 71.56. waiting time: 0.00 days.
# 72.10: COMPLEX_NEURO arrival.
# Patient 23 (COMPLEX_NEURO)             arrives at 72.10.
# Patient 23 (COMPLEX_NEURO)  gets a bed at 72.10. waiting time: 0.00 days.
# 72.33: TIA arrival.
# Patient 7 (TIA)             arrives at 72.33.
# Patient 7 (TIA)  gets a bed at 72.33. waiting time: 0.00 days.
# Patient 21 (COMPLEX_NEURO)                 leaves at 72.79.
# Patient 21 (COMPLEX_NEURO)                 has a length of stay of 3.10 days.
# 73.86: STROKE arrival.
# Patient 54 (STROKE)             arrives at 73.86.
# Patient 54 (STROKE)  gets a bed at 73.86. waiting time: 0.00 days.
# Patient 23 (COMPLEX_NEURO)                 leaves at 73.93.
# Patient 23 (COMPLEX_NEURO)                 has a length of stay of 1.83 days.
# 74.40: STROKE arrival.
# Patient 55 (STROKE)             arrives at 74.40.
# Patient 55 (STROKE)  gets a bed at 74.40. waiting time: 0.00 days.
# 74.79: STROKE arrival.
# Patient 56 (STROKE)             arrives at 74.79.
# 75.34: STROKE arrival.
# Patient 57 (STROKE)             arrives at 75.34.
# Patient 7 (TIA)                 leaves at 75.80.
# Patient 7 (TIA)                 has a length of stay of 3.47 days.
# Patient 56 (STROKE)  gets a bed at 75.80. waiting time: 1.02 days.
# Patient 54 (STROKE)                 leaves at 76.09.
# Patient 54 (STROKE)                 has a length of stay of 2.22 days.
# Patient 57 (STROKE)  gets a bed at 76.09. waiting time: 0.74 days.
# Patient 50 (STROKE)                 leaves at 76.21.
# Patient 50 (STROKE)                 has a length of stay of 5.93 days.
# Patient 55 (STROKE)                 leaves at 76.61.
# Patient 55 (STROKE)                 has a length of stay of 2.22 days.
# 76.85: STROKE arrival.
# Patient 58 (STROKE)             arrives at 76.85.
# Patient 58 (STROKE)  gets a bed at 76.85. waiting time: 0.00 days.
# Patient 56 (STROKE)                 leaves at 76.92.
# Patient 56 (STROKE)                 has a length of stay of 1.12 days.
# Patient 35 (STROKE)                 leaves at 77.49.
# Patient 35 (STROKE)                 has a length of stay of 24.89 days.
# 77.94: STROKE arrival.
# Patient 59 (STROKE)             arrives at 77.94.
# Patient 59 (STROKE)  gets a bed at 77.94. waiting time: 0.00 days.
# 78.04: STROKE arrival.
# Patient 60 (STROKE)             arrives at 78.04.
# Patient 60 (STROKE)  gets a bed at 78.04. waiting time: 0.00 days.
# Patient 53 (STROKE)                 leaves at 78.39.
# Patient 53 (STROKE)                 has a length of stay of 6.83 days.
# 79.18: STROKE arrival.
# Patient 61 (STROKE)             arrives at 79.18.
# Patient 61 (STROKE)  gets a bed at 79.18. waiting time: 0.00 days.
# Patient 60 (STROKE)                 leaves at 79.32.
# Patient 60 (STROKE)                 has a length of stay of 1.27 days.
# Patient 51 (STROKE)                 leaves at 79.40.
# Patient 51 (STROKE)                 has a length of stay of 8.78 days.
# Patient 52 (STROKE)                 leaves at 80.24.
# Patient 52 (STROKE)                 has a length of stay of 8.97 days.
# Patient 61 (STROKE)                 leaves at 80.37.
# Patient 61 (STROKE)                 has a length of stay of 1.19 days.
# 80.45: STROKE arrival.
# Patient 62 (STROKE)             arrives at 80.45.
# Patient 62 (STROKE)  gets a bed at 80.45. waiting time: 0.00 days.
# 80.80: STROKE arrival.
# Patient 63 (STROKE)             arrives at 80.80.
# Patient 63 (STROKE)  gets a bed at 80.80. waiting time: 0.00 days.
# Patient 62 (STROKE)                 leaves at 81.24.
# Patient 62 (STROKE)                 has a length of stay of 0.79 days.
# Patient 57 (STROKE)                 leaves at 81.30.
# Patient 57 (STROKE)                 has a length of stay of 5.21 days.
# Patient 59 (STROKE)                 leaves at 81.30.
# Patient 59 (STROKE)                 has a length of stay of 3.36 days.
# 81.49: COMPLEX_NEURO arrival.
# Patient 24 (COMPLEX_NEURO)             arrives at 81.49.
# Patient 24 (COMPLEX_NEURO)  gets a bed at 81.49. waiting time: 0.00 days.
# Patient 58 (STROKE)                 leaves at 81.81.
# Patient 58 (STROKE)                 has a length of stay of 4.96 days.
# 82.35: STROKE arrival.
# Patient 64 (STROKE)             arrives at 82.35.
# Patient 64 (STROKE)  gets a bed at 82.35. waiting time: 0.00 days.
# 83.19: STROKE arrival.
# Patient 65 (STROKE)             arrives at 83.19.
# Patient 65 (STROKE)  gets a bed at 83.19. waiting time: 0.00 days.
# 83.41: OTHER arrival.
# Patient 26 (OTHER)             arrives at 83.41.
# Patient 26 (OTHER)  gets a bed at 83.41. waiting time: 0.00 days.
# Patient 26 (OTHER)                 leaves at 84.15.
# Patient 26 (OTHER)                 has a length of stay of 0.74 days.
# 84.18: STROKE arrival.
# Patient 66 (STROKE)             arrives at 84.18.
# Patient 66 (STROKE)  gets a bed at 84.18. waiting time: 0.00 days.
# Patient 65 (STROKE)                 leaves at 84.32.
# Patient 65 (STROKE)                 has a length of stay of 1.13 days.
# Patient 63 (STROKE)                 leaves at 84.33.
# Patient 63 (STROKE)                 has a length of stay of 3.52 days.
# 84.38: OTHER arrival.
# Patient 27 (OTHER)             arrives at 84.38.
# Patient 27 (OTHER)  gets a bed at 84.38. waiting time: 0.00 days.
# Patient 24 (COMPLEX_NEURO)                 leaves at 84.42.
# Patient 24 (COMPLEX_NEURO)                 has a length of stay of 2.93 days.
# Patient 27 (OTHER)                 leaves at 84.71.
# Patient 27 (OTHER)                 has a length of stay of 0.33 days.
# 85.15: STROKE arrival.
# Patient 67 (STROKE)             arrives at 85.15.
# Patient 67 (STROKE)  gets a bed at 85.15. waiting time: 0.00 days.
# 85.64: STROKE arrival.
# Patient 68 (STROKE)             arrives at 85.64.
# Patient 68 (STROKE)  gets a bed at 85.64. waiting time: 0.00 days.
# 87.83: STROKE arrival.
# Patient 69 (STROKE)             arrives at 87.83.
# Patient 69 (STROKE)  gets a bed at 87.83. waiting time: 0.00 days.
# 88.02: STROKE arrival.
# Patient 70 (STROKE)             arrives at 88.02.
# Patient 70 (STROKE)  gets a bed at 88.02. waiting time: 0.00 days.
# 88.23: STROKE arrival.
# Patient 71 (STROKE)             arrives at 88.23.
# Patient 71 (STROKE)  gets a bed at 88.23. waiting time: 0.00 days.
# 88.43: STROKE arrival.
# Patient 72 (STROKE)             arrives at 88.43.
# Patient 72 (STROKE)  gets a bed at 88.43. waiting time: 0.00 days.
# 88.61: STROKE arrival.
# Patient 73 (STROKE)             arrives at 88.61.
# 88.93: COMPLEX_NEURO arrival.
# Patient 25 (COMPLEX_NEURO)             arrives at 88.93.
# Patient 66 (STROKE)                 leaves at 89.39.
# Patient 66 (STROKE)                 has a length of stay of 5.21 days.
# Patient 73 (STROKE)  gets a bed at 89.39. waiting time: 0.78 days.
# 89.75: STROKE arrival.
# Patient 74 (STROKE)             arrives at 89.75.
# 89.77: COMPLEX_NEURO arrival.
# Patient 26 (COMPLEX_NEURO)             arrives at 89.77.
# Patient 69 (STROKE)                 leaves at 90.58.
# Patient 69 (STROKE)                 has a length of stay of 2.75 days.
# Patient 25 (COMPLEX_NEURO)  gets a bed at 90.58. waiting time: 1.65 days.
# Patient 64 (STROKE)                 leaves at 90.58.
# Patient 64 (STROKE)                 has a length of stay of 8.23 days.
# Patient 74 (STROKE)  gets a bed at 90.58. waiting time: 0.83 days.
# 91.03: STROKE arrival.
# Patient 75 (STROKE)             arrives at 91.03.
# 91.05: COMPLEX_NEURO arrival.
# Patient 27 (COMPLEX_NEURO)             arrives at 91.05.
# Patient 74 (STROKE)                 leaves at 91.61.
# Patient 74 (STROKE)                 has a length of stay of 1.03 days.
# Patient 26 (COMPLEX_NEURO)  gets a bed at 91.61. waiting time: 1.84 days.
# 91.71: STROKE arrival.
# Patient 76 (STROKE)             arrives at 91.71.
# Patient 72 (STROKE)                 leaves at 92.68.
# Patient 72 (STROKE)                 has a length of stay of 4.25 days.
# Patient 75 (STROKE)  gets a bed at 92.68. waiting time: 1.65 days.
# Patient 26 (COMPLEX_NEURO)                 leaves at 93.30.
# Patient 26 (COMPLEX_NEURO)                 has a length of stay of 1.70 days.
# Patient 27 (COMPLEX_NEURO)  gets a bed at 93.30. waiting time: 2.25 days.
# 93.41: OTHER arrival.
# Patient 28 (OTHER)             arrives at 93.41.
# 93.49: STROKE arrival.
# Patient 77 (STROKE)             arrives at 93.49.
# Patient 49 (STROKE)                 leaves at 93.58.
# Patient 49 (STROKE)                 has a length of stay of 24.16 days.
# Patient 76 (STROKE)  gets a bed at 93.58. waiting time: 1.87 days.
# 94.15: STROKE arrival.
# Patient 78 (STROKE)             arrives at 94.15.
# Patient 25 (COMPLEX_NEURO)                 leaves at 94.28.
# Patient 25 (COMPLEX_NEURO)                 has a length of stay of 3.71 days.
# Patient 28 (OTHER)  gets a bed at 94.28. waiting time: 0.87 days.
# Patient 67 (STROKE)                 leaves at 94.29.
# Patient 67 (STROKE)                 has a length of stay of 9.14 days.
# Patient 77 (STROKE)  gets a bed at 94.29. waiting time: 0.80 days.
# 94.46: OTHER arrival.
# Patient 29 (OTHER)             arrives at 94.46.
# 94.86: OTHER arrival.
# Patient 30 (OTHER)             arrives at 94.86.
# 95.35: OTHER arrival.
# Patient 31 (OTHER)             arrives at 95.35.
# Patient 28 (OTHER)                 leaves at 95.74.
# Patient 28 (OTHER)                 has a length of stay of 1.46 days.
# Patient 78 (STROKE)  gets a bed at 95.74. waiting time: 1.59 days.
# 95.99: STROKE arrival.
# Patient 79 (STROKE)             arrives at 95.99.
# 96.26: COMPLEX_NEURO arrival.
# Patient 28 (COMPLEX_NEURO)             arrives at 96.26.
# Patient 76 (STROKE)                 leaves at 96.46.
# Patient 76 (STROKE)                 has a length of stay of 2.88 days.
# Patient 29 (OTHER)  gets a bed at 96.46. waiting time: 2.00 days.
# Patient 29 (OTHER)                 leaves at 97.58.
# Patient 29 (OTHER)                 has a length of stay of 1.12 days.
# Patient 30 (OTHER)  gets a bed at 97.58. waiting time: 2.72 days.
# Patient 75 (STROKE)                 leaves at 98.38.
# Patient 75 (STROKE)                 has a length of stay of 5.70 days.
# Patient 31 (OTHER)  gets a bed at 98.38. waiting time: 3.03 days.
# 98.45: STROKE arrival.
# Patient 80 (STROKE)             arrives at 98.45.
# 98.47: OTHER arrival.
# Patient 32 (OTHER)             arrives at 98.47.
# Patient 27 (COMPLEX_NEURO)                 leaves at 99.16.
# Patient 27 (COMPLEX_NEURO)                 has a length of stay of 5.86 days.
# Patient 79 (STROKE)  gets a bed at 99.16. waiting time: 3.17 days.
# 99.68: STROKE arrival.
# Patient 81 (STROKE)             arrives at 99.68.
# 99.81: STROKE arrival.
# Patient 82 (STROKE)             arrives at 99.81.
# 100.39: STROKE arrival.
# Patient 83 (STROKE)             arrives at 100.39.
# 100.42: COMPLEX_NEURO arrival.
# Patient 29 (COMPLEX_NEURO)             arrives at 100.42.
# Patient 68 (STROKE)                 leaves at 100.51.
# Patient 68 (STROKE)                 has a length of stay of 14.87 days.
# Patient 28 (COMPLEX_NEURO)  gets a bed at 100.51. waiting time: 4.25 days.
# 101.27: STROKE arrival.
# Patient 84 (STROKE)             arrives at 101.27.
# Patient 30 (OTHER)                 leaves at 101.27.
# Patient 30 (OTHER)                 has a length of stay of 3.69 days.
# Patient 80 (STROKE)  gets a bed at 101.27. waiting time: 2.82 days.
# Patient 78 (STROKE)                 leaves at 101.69.
# Patient 78 (STROKE)                 has a length of stay of 5.95 days.
# Patient 32 (OTHER)  gets a bed at 101.69. waiting time: 3.22 days.
# Patient 46 (STROKE)                 leaves at 101.73.
# Patient 46 (STROKE)                 has a length of stay of 34.74 days.
# Patient 81 (STROKE)  gets a bed at 101.73. waiting time: 2.05 days.
# Patient 79 (STROKE)                 leaves at 101.75.
# Patient 79 (STROKE)                 has a length of stay of 2.59 days.
# Patient 82 (STROKE)  gets a bed at 101.75. waiting time: 1.94 days.
# 103.55: OTHER arrival.
# Patient 33 (OTHER)             arrives at 103.55.
# 104.27: STROKE arrival.
# Patient 85 (STROKE)             arrives at 104.27.
# Patient 80 (STROKE)                 leaves at 104.77.
# Patient 80 (STROKE)                 has a length of stay of 3.50 days.
# Patient 83 (STROKE)  gets a bed at 104.77. waiting time: 4.39 days.
# Patient 31 (OTHER)                 leaves at 105.17.
# Patient 31 (OTHER)                 has a length of stay of 6.79 days.
# Patient 29 (COMPLEX_NEURO)  gets a bed at 105.17. waiting time: 4.74 days.
# Patient 71 (STROKE)                 leaves at 105.30.
# Patient 71 (STROKE)                 has a length of stay of 17.07 days.
# Patient 84 (STROKE)  gets a bed at 105.30. waiting time: 4.03 days.
# 105.50: STROKE arrival.
# Patient 86 (STROKE)             arrives at 105.50.
# 105.84: STROKE arrival.
# Patient 87 (STROKE)             arrives at 105.84.
# Patient 28 (COMPLEX_NEURO)                 leaves at 106.07.
# Patient 28 (COMPLEX_NEURO)                 has a length of stay of 5.55 days.
# Patient 33 (OTHER)  gets a bed at 106.07. waiting time: 2.51 days.
# Patient 81 (STROKE)                 leaves at 106.16.
# Patient 81 (STROKE)                 has a length of stay of 4.43 days.
# Patient 85 (STROKE)  gets a bed at 106.16. waiting time: 1.90 days.
# Patient 29 (COMPLEX_NEURO)                 leaves at 106.51.
# Patient 29 (COMPLEX_NEURO)                 has a length of stay of 1.34 days.
# Patient 86 (STROKE)  gets a bed at 106.51. waiting time: 1.01 days.
# Patient 73 (STROKE)                 leaves at 106.99.
# Patient 73 (STROKE)                 has a length of stay of 17.59 days.
# Patient 87 (STROKE)  gets a bed at 106.99. waiting time: 1.14 days.
# 107.39: OTHER arrival.
# Patient 34 (OTHER)             arrives at 107.39.
# Patient 70 (STROKE)                 leaves at 108.42.
# Patient 70 (STROKE)                 has a length of stay of 20.40 days.
# Patient 34 (OTHER)  gets a bed at 108.42. waiting time: 1.02 days.
# 109.04: STROKE arrival.
# Patient 88 (STROKE)             arrives at 109.04.
# 109.98: OTHER arrival.
# Patient 35 (OTHER)             arrives at 109.98.
# Patient 32 (OTHER)                 leaves at 110.39.
# Patient 32 (OTHER)                 has a length of stay of 8.70 days.
# Patient 88 (STROKE)  gets a bed at 110.39. waiting time: 1.35 days.
# Patient 77 (STROKE)                 leaves at 110.76.
# Patient 77 (STROKE)                 has a length of stay of 16.47 days.
# Patient 35 (OTHER)  gets a bed at 110.76. waiting time: 0.78 days.
# 111.08: TIA arrival.
# Patient 8 (TIA)             arrives at 111.08.
# 111.23: OTHER arrival.
# Patient 36 (OTHER)             arrives at 111.23.
# Patient 82 (STROKE)                 leaves at 111.33.
# Patient 82 (STROKE)                 has a length of stay of 9.58 days.
# Patient 8 (TIA)  gets a bed at 111.33. waiting time: 0.25 days.
# 111.80: STROKE arrival.
# Patient 89 (STROKE)             arrives at 111.80.
# 112.10: STROKE arrival.
# Patient 90 (STROKE)             arrives at 112.10.
# 112.14: OTHER arrival.
# Patient 37 (OTHER)             arrives at 112.14.
# Patient 86 (STROKE)                 leaves at 112.24.
# Patient 86 (STROKE)                 has a length of stay of 5.73 days.
# Patient 36 (OTHER)  gets a bed at 112.24. waiting time: 1.01 days.
# Patient 35 (OTHER)                 leaves at 112.58.
# Patient 35 (OTHER)                 has a length of stay of 1.82 days.
# Patient 89 (STROKE)  gets a bed at 112.58. waiting time: 0.78 days.
# 112.88: STROKE arrival.
# Patient 91 (STROKE)             arrives at 112.88.
# Patient 8 (TIA)                 leaves at 113.22.
# Patient 8 (TIA)                 has a length of stay of 1.89 days.
# Patient 90 (STROKE)  gets a bed at 113.22. waiting time: 1.12 days.
# Patient 87 (STROKE)                 leaves at 113.56.
# Patient 87 (STROKE)                 has a length of stay of 6.57 days.
# Patient 37 (OTHER)  gets a bed at 113.56. waiting time: 1.42 days.
# 113.74: STROKE arrival.
# Patient 92 (STROKE)             arrives at 113.74.
# Patient 33 (OTHER)                 leaves at 113.91.
# Patient 33 (OTHER)                 has a length of stay of 7.85 days.
# Patient 91 (STROKE)  gets a bed at 113.91. waiting time: 1.03 days.
# Patient 84 (STROKE)                 leaves at 113.93.
# Patient 84 (STROKE)                 has a length of stay of 8.63 days.
# Patient 92 (STROKE)  gets a bed at 113.93. waiting time: 0.19 days.
# Patient 36 (OTHER)                 leaves at 113.96.
# Patient 36 (OTHER)                 has a length of stay of 1.72 days.
# Patient 89 (STROKE)                 leaves at 114.54.
# Patient 89 (STROKE)                 has a length of stay of 1.96 days.
# 114.63: OTHER arrival.
# Patient 38 (OTHER)             arrives at 114.63.
# Patient 38 (OTHER)  gets a bed at 114.63. waiting time: 0.00 days.
# 114.68: STROKE arrival.
# Patient 93 (STROKE)             arrives at 114.68.
# Patient 93 (STROKE)  gets a bed at 114.68. waiting time: 0.00 days.
# 115.46: STROKE arrival.
# Patient 94 (STROKE)             arrives at 115.46.
# 116.25: OTHER arrival.
# Patient 39 (OTHER)             arrives at 116.25.
# Patient 88 (STROKE)                 leaves at 116.30.
# Patient 88 (STROKE)                 has a length of stay of 5.91 days.
# Patient 94 (STROKE)  gets a bed at 116.30. waiting time: 0.84 days.
# Patient 83 (STROKE)                 leaves at 116.48.
# Patient 83 (STROKE)                 has a length of stay of 11.71 days.
# Patient 39 (OTHER)  gets a bed at 116.48. waiting time: 0.23 days.
# 116.54: TIA arrival.
# Patient 9 (TIA)             arrives at 116.54.
# Patient 38 (OTHER)                 leaves at 116.85.
# Patient 38 (OTHER)                 has a length of stay of 2.22 days.
# Patient 9 (TIA)  gets a bed at 116.85. waiting time: 0.31 days.
# 116.90: STROKE arrival.
# Patient 95 (STROKE)             arrives at 116.90.
# Patient 39 (OTHER)                 leaves at 116.93.
# Patient 39 (OTHER)                 has a length of stay of 0.45 days.
# Patient 95 (STROKE)  gets a bed at 116.93. waiting time: 0.03 days.
# Patient 93 (STROKE)                 leaves at 116.99.
# Patient 93 (STROKE)                 has a length of stay of 2.31 days.
# 117.17: STROKE arrival.
# Patient 96 (STROKE)             arrives at 117.17.
# Patient 96 (STROKE)  gets a bed at 117.17. waiting time: 0.00 days.
# 117.45: COMPLEX_NEURO arrival.
# Patient 30 (COMPLEX_NEURO)             arrives at 117.45.
# Patient 37 (OTHER)                 leaves at 117.67.
# Patient 37 (OTHER)                 has a length of stay of 4.12 days.
# Patient 30 (COMPLEX_NEURO)  gets a bed at 117.67. waiting time: 0.22 days.
# Patient 90 (STROKE)                 leaves at 118.03.
# Patient 90 (STROKE)                 has a length of stay of 4.81 days.
# Patient 91 (STROKE)                 leaves at 118.08.
# Patient 91 (STROKE)                 has a length of stay of 4.17 days.
# 118.24: COMPLEX_NEURO arrival.
# Patient 31 (COMPLEX_NEURO)             arrives at 118.24.
# Patient 31 (COMPLEX_NEURO)  gets a bed at 118.24. waiting time: 0.00 days.
# 118.43: STROKE arrival.
# Patient 97 (STROKE)             arrives at 118.43.
# Patient 97 (STROKE)  gets a bed at 118.43. waiting time: 0.00 days.
# Patient 30 (COMPLEX_NEURO)                 leaves at 118.49.
# Patient 30 (COMPLEX_NEURO)                 has a length of stay of 0.82 days.
# Patient 94 (STROKE)                 leaves at 118.57.
# Patient 94 (STROKE)                 has a length of stay of 2.27 days.
# Patient 34 (OTHER)                 leaves at 119.32.
# Patient 34 (OTHER)                 has a length of stay of 10.91 days.
# 119.36: COMPLEX_NEURO arrival.
# Patient 32 (COMPLEX_NEURO)             arrives at 119.36.
# Patient 32 (COMPLEX_NEURO)  gets a bed at 119.36. waiting time: 0.00 days.
# Patient 9 (TIA)                 leaves at 119.58.
# Patient 9 (TIA)                 has a length of stay of 2.73 days.
# Patient 92 (STROKE)                 leaves at 119.98.
# Patient 92 (STROKE)                 has a length of stay of 6.05 days.
# Patient 31 (COMPLEX_NEURO)                 leaves at 120.62.
# Patient 31 (COMPLEX_NEURO)                 has a length of stay of 2.39 days.
# Patient 96 (STROKE)                 leaves at 120.76.
# Patient 96 (STROKE)                 has a length of stay of 3.58 days.
# Patient 95 (STROKE)                 leaves at 120.90.
# Patient 95 (STROKE)                 has a length of stay of 3.97 days.
# 122.22: OTHER arrival.
# Patient 40 (OTHER)             arrives at 122.22.
# Patient 40 (OTHER)  gets a bed at 122.22. waiting time: 0.00 days.
# Patient 97 (STROKE)                 leaves at 122.37.
# Patient 97 (STROKE)                 has a length of stay of 3.94 days.
# Patient 32 (COMPLEX_NEURO)                 leaves at 122.39.
# Patient 32 (COMPLEX_NEURO)                 has a length of stay of 3.03 days.
# 122.73: STROKE arrival.
# Patient 98 (STROKE)             arrives at 122.73.
# Patient 98 (STROKE)  gets a bed at 122.73. waiting time: 0.00 days.
# 122.79: STROKE arrival.
# Patient 99 (STROKE)             arrives at 122.79.
# Patient 99 (STROKE)  gets a bed at 122.79. waiting time: 0.00 days.
# Patient 40 (OTHER)                 leaves at 123.22.
# Patient 40 (OTHER)                 has a length of stay of 1.00 days.
# 123.33: STROKE arrival.
# Patient 100 (STROKE)             arrives at 123.33.
# ...
# Patient 161 (STROKE)                 has a length of stay of 8.22 days.
# Patient 15 (TIA)  gets a bed at 213.03. waiting time: 2.13 days.
# 213.38: STROKE arrival.
# Patient 171 (STROKE)             arrives at 213.38.
# Patient 15 (TIA)                 leaves at 213.44.
# Patient 15 (TIA)                 has a length of stay of 0.40 days.
# Patient 16 (TIA)  gets a bed at 213.44. waiting time: 2.04 days.
# 213.66: TIA arrival.
# Patient 17 (TIA)             arrives at 213.66.
# Patient 63 (OTHER)                 leaves at 214.04.
# Patient 63 (OTHER)                 has a length of stay of 3.24 days.
# Patient 169 (STROKE)  gets a bed at 214.04. waiting time: 2.22 days.
# 215.02: OTHER arrival.
# Patient 64 (OTHER)             arrives at 215.02.
# Patient 160 (STROKE)                 leaves at 215.37.
# Patient 160 (STROKE)                 has a length of stay of 12.34 days.
# Patient 170 (STROKE)  gets a bed at 215.37. waiting time: 3.45 days.
# 215.57: STROKE arrival.
# Patient 172 (STROKE)             arrives at 215.57.
# 215.99: COMPLEX_NEURO arrival.
# Patient 52 (COMPLEX_NEURO)             arrives at 215.99.
# 216.02: OTHER arrival.
# Patient 65 (OTHER)             arrives at 216.02.
# Patient 48 (COMPLEX_NEURO)                 leaves at 216.06.
# Patient 48 (COMPLEX_NEURO)                 has a length of stay of 7.01 days.
# Patient 50 (COMPLEX_NEURO)  gets a bed at 216.06. waiting time: 3.70 days.
# 216.66: COMPLEX_NEURO arrival.
# Patient 53 (COMPLEX_NEURO)             arrives at 216.66.
# 216.94: COMPLEX_NEURO arrival.
# Patient 54 (COMPLEX_NEURO)             arrives at 216.94.
# 216.95: OTHER arrival.
# Patient 66 (OTHER)             arrives at 216.95.
# Patient 144 (STROKE)                 leaves at 216.96.
# Patient 144 (STROKE)                 has a length of stay of 23.75 days.
# Patient 51 (COMPLEX_NEURO)  gets a bed at 216.96. waiting time: 4.06 days.
# 216.99: STROKE arrival.
# Patient 173 (STROKE)             arrives at 216.99.
# 217.45: STROKE arrival.
# Patient 174 (STROKE)             arrives at 217.45.
# Patient 165 (STROKE)                 leaves at 217.70.
# Patient 165 (STROKE)                 has a length of stay of 9.74 days.
# Patient 171 (STROKE)  gets a bed at 217.70. waiting time: 4.32 days.
# Patient 16 (TIA)                 leaves at 218.30.
# Patient 16 (TIA)                 has a length of stay of 4.87 days.
# Patient 17 (TIA)  gets a bed at 218.30. waiting time: 4.64 days.
# Patient 168 (STROKE)                 leaves at 218.51.
# Patient 168 (STROKE)                 has a length of stay of 8.31 days.
# Patient 64 (OTHER)  gets a bed at 218.51. waiting time: 3.49 days.
# 218.83: OTHER arrival.
# Patient 67 (OTHER)             arrives at 218.83.
# 218.87: OTHER arrival.
# Patient 68 (OTHER)             arrives at 218.87.
# Patient 167 (STROKE)                 leaves at 219.16.
# Patient 167 (STROKE)                 has a length of stay of 9.04 days.
# Patient 172 (STROKE)  gets a bed at 219.16. waiting time: 3.59 days.
# Patient 51 (COMPLEX_NEURO)                 leaves at 219.37.
# Patient 51 (COMPLEX_NEURO)                 has a length of stay of 2.41 days.
# Patient 52 (COMPLEX_NEURO)  gets a bed at 219.37. waiting time: 3.38 days.
# 219.48: COMPLEX_NEURO arrival.
# Patient 55 (COMPLEX_NEURO)             arrives at 219.48.
# 220.38: STROKE arrival.
# Patient 175 (STROKE)             arrives at 220.38.
# Patient 171 (STROKE)                 leaves at 220.61.
# Patient 171 (STROKE)                 has a length of stay of 2.90 days.
# Patient 65 (OTHER)  gets a bed at 220.61. waiting time: 4.59 days.
# 221.30: STROKE arrival.
# Patient 176 (STROKE)             arrives at 221.30.
# 221.33: STROKE arrival.
# Patient 177 (STROKE)             arrives at 221.33.
# 221.44: STROKE arrival.
# Patient 178 (STROKE)             arrives at 221.44.
# 221.60: STROKE arrival.
# Patient 179 (STROKE)             arrives at 221.60.
# Patient 52 (COMPLEX_NEURO)                 leaves at 221.85.
# Patient 52 (COMPLEX_NEURO)                 has a length of stay of 2.48 days.
# Patient 53 (COMPLEX_NEURO)  gets a bed at 221.85. waiting time: 5.18 days.
# 221.86: COMPLEX_NEURO arrival.
# Patient 56 (COMPLEX_NEURO)             arrives at 221.86.
# Patient 65 (OTHER)                 leaves at 222.08.
# Patient 65 (OTHER)                 has a length of stay of 1.48 days.
# Patient 54 (COMPLEX_NEURO)  gets a bed at 222.08. waiting time: 5.14 days.
# Patient 169 (STROKE)                 leaves at 222.49.
# Patient 169 (STROKE)                 has a length of stay of 8.45 days.
# Patient 66 (OTHER)  gets a bed at 222.49. waiting time: 5.55 days.
# 222.65: TIA arrival.
# Patient 18 (TIA)             arrives at 222.65.
# 222.73: STROKE arrival.
# Patient 180 (STROKE)             arrives at 222.73.
# Patient 170 (STROKE)                 leaves at 222.96.
# Patient 170 (STROKE)                 has a length of stay of 7.58 days.
# Patient 173 (STROKE)  gets a bed at 222.96. waiting time: 5.97 days.
# 223.10: COMPLEX_NEURO arrival.
# Patient 57 (COMPLEX_NEURO)             arrives at 223.10.
# 223.22: OTHER arrival.
# Patient 69 (OTHER)             arrives at 223.22.
# Patient 166 (STROKE)                 leaves at 223.34.
# Patient 166 (STROKE)                 has a length of stay of 13.75 days.
# Patient 174 (STROKE)  gets a bed at 223.34. waiting time: 5.90 days.
# 223.44: STROKE arrival.
# Patient 181 (STROKE)             arrives at 223.44.
# Patient 53 (COMPLEX_NEURO)                 leaves at 223.60.
# Patient 53 (COMPLEX_NEURO)                 has a length of stay of 1.75 days.
# Patient 67 (OTHER)  gets a bed at 223.60. waiting time: 4.77 days.
# Patient 64 (OTHER)                 leaves at 224.18.
# Patient 64 (OTHER)                 has a length of stay of 5.68 days.
# Patient 68 (OTHER)  gets a bed at 224.18. waiting time: 5.31 days.
# Patient 154 (STROKE)                 leaves at 224.22.
# Patient 154 (STROKE)                 has a length of stay of 26.51 days.
# Patient 55 (COMPLEX_NEURO)  gets a bed at 224.22. waiting time: 4.74 days.
# Patient 67 (OTHER)                 leaves at 224.72.
# Patient 67 (OTHER)                 has a length of stay of 1.12 days.
# Patient 175 (STROKE)  gets a bed at 224.72. waiting time: 4.34 days.
# 225.06: STROKE arrival.
# Patient 182 (STROKE)             arrives at 225.06.
# Patient 175 (STROKE)                 leaves at 225.29.
# Patient 175 (STROKE)                 has a length of stay of 0.57 days.
# Patient 176 (STROKE)  gets a bed at 225.29. waiting time: 4.00 days.
# Patient 54 (COMPLEX_NEURO)                 leaves at 225.32.
# Patient 54 (COMPLEX_NEURO)                 has a length of stay of 3.24 days.
# Patient 177 (STROKE)  gets a bed at 225.32. waiting time: 3.99 days.
# Patient 68 (OTHER)                 leaves at 225.46.
# Patient 68 (OTHER)                 has a length of stay of 1.28 days.
# Patient 178 (STROKE)  gets a bed at 225.46. waiting time: 4.01 days.
# Patient 172 (STROKE)                 leaves at 226.09.
# Patient 172 (STROKE)                 has a length of stay of 6.93 days.
# Patient 179 (STROKE)  gets a bed at 226.09. waiting time: 4.49 days.
# 226.11: STROKE arrival.
# Patient 183 (STROKE)             arrives at 226.11.
# Patient 66 (OTHER)                 leaves at 226.34.
# Patient 66 (OTHER)                 has a length of stay of 3.84 days.
# Patient 56 (COMPLEX_NEURO)  gets a bed at 226.34. waiting time: 4.48 days.
# Patient 177 (STROKE)                 leaves at 226.59.
# Patient 177 (STROKE)                 has a length of stay of 1.27 days.
# Patient 18 (TIA)  gets a bed at 226.59. waiting time: 3.94 days.
# 226.69: STROKE arrival.
# Patient 184 (STROKE)             arrives at 226.69.
# Patient 56 (COMPLEX_NEURO)                 leaves at 226.71.
# Patient 56 (COMPLEX_NEURO)                 has a length of stay of 0.37 days.
# Patient 180 (STROKE)  gets a bed at 226.71. waiting time: 3.98 days.
# Patient 50 (COMPLEX_NEURO)                 leaves at 226.73.
# Patient 50 (COMPLEX_NEURO)                 has a length of stay of 10.68 days.
# Patient 57 (COMPLEX_NEURO)  gets a bed at 226.73. waiting time: 3.63 days.
# Patient 55 (COMPLEX_NEURO)                 leaves at 226.87.
# Patient 55 (COMPLEX_NEURO)                 has a length of stay of 2.65 days.
# Patient 69 (OTHER)  gets a bed at 226.87. waiting time: 3.65 days.
# Patient 179 (STROKE)                 leaves at 227.87.
# Patient 179 (STROKE)                 has a length of stay of 1.77 days.
# Patient 181 (STROKE)  gets a bed at 227.87. waiting time: 4.43 days.
# 228.02: STROKE arrival.
# Patient 185 (STROKE)             arrives at 228.02.
# Patient 69 (OTHER)                 leaves at 228.09.
# Patient 69 (OTHER)                 has a length of stay of 1.22 days.
# Patient 182 (STROKE)  gets a bed at 228.09. waiting time: 3.02 days.
# Patient 18 (TIA)                 leaves at 228.17.
# Patient 18 (TIA)                 has a length of stay of 1.58 days.
# Patient 183 (STROKE)  gets a bed at 228.17. waiting time: 2.05 days.
# Patient 17 (TIA)                 leaves at 228.40.
# Patient 17 (TIA)                 has a length of stay of 10.10 days.
# Patient 184 (STROKE)  gets a bed at 228.40. waiting time: 1.71 days.
# 228.51: OTHER arrival.
# Patient 70 (OTHER)             arrives at 228.51.
# 228.59: STROKE arrival.
# Patient 186 (STROKE)             arrives at 228.59.
# Patient 174 (STROKE)                 leaves at 228.89.
# Patient 174 (STROKE)                 has a length of stay of 5.55 days.
# Patient 185 (STROKE)  gets a bed at 228.89. waiting time: 0.87 days.
# Patient 182 (STROKE)                 leaves at 228.90.
# Patient 182 (STROKE)                 has a length of stay of 0.81 days.
# Patient 70 (OTHER)  gets a bed at 228.90. waiting time: 0.39 days.
# Patient 57 (COMPLEX_NEURO)                 leaves at 228.90.
# Patient 57 (COMPLEX_NEURO)                 has a length of stay of 2.17 days.
# Patient 186 (STROKE)  gets a bed at 228.90. waiting time: 0.31 days.
# 228.93: STROKE arrival.
# Patient 187 (STROKE)             arrives at 228.93.
# 229.05: STROKE arrival.
# Patient 188 (STROKE)             arrives at 229.05.
# 229.13: STROKE arrival.
# Patient 189 (STROKE)             arrives at 229.13.
# 229.17: TIA arrival.
# Patient 19 (TIA)             arrives at 229.17.
# 229.34: OTHER arrival.
# Patient 71 (OTHER)             arrives at 229.34.
# 229.36: STROKE arrival.
# Patient 190 (STROKE)             arrives at 229.36.
# 229.92: OTHER arrival.
# Patient 72 (OTHER)             arrives at 229.92.
# Patient 70 (OTHER)                 leaves at 229.92.
# Patient 70 (OTHER)                 has a length of stay of 1.03 days.
# Patient 187 (STROKE)  gets a bed at 229.92. waiting time: 0.99 days.
# Patient 173 (STROKE)                 leaves at 230.02.
# Patient 173 (STROKE)                 has a length of stay of 7.06 days.
# Patient 188 (STROKE)  gets a bed at 230.02. waiting time: 0.97 days.
# 230.82: OTHER arrival.
# Patient 73 (OTHER)             arrives at 230.82.
# Patient 184 (STROKE)                 leaves at 230.96.
# Patient 184 (STROKE)                 has a length of stay of 2.56 days.
# Patient 189 (STROKE)  gets a bed at 230.96. waiting time: 1.83 days.
# Patient 178 (STROKE)                 leaves at 231.02.
# Patient 178 (STROKE)                 has a length of stay of 5.57 days.
# Patient 19 (TIA)  gets a bed at 231.02. waiting time: 1.86 days.
# 231.03: OTHER arrival.
# Patient 74 (OTHER)             arrives at 231.03.
# Patient 181 (STROKE)                 leaves at 231.29.
# Patient 181 (STROKE)                 has a length of stay of 3.42 days.
# Patient 71 (OTHER)  gets a bed at 231.29. waiting time: 1.94 days.
# Patient 19 (TIA)                 leaves at 232.15.
# Patient 19 (TIA)                 has a length of stay of 1.13 days.
# Patient 190 (STROKE)  gets a bed at 232.15. waiting time: 2.79 days.
# 232.39: STROKE arrival.
# Patient 191 (STROKE)             arrives at 232.39.
# Patient 188 (STROKE)                 leaves at 232.49.
# Patient 188 (STROKE)                 has a length of stay of 2.47 days.
# Patient 72 (OTHER)  gets a bed at 232.49. waiting time: 2.57 days.
# Patient 185 (STROKE)                 leaves at 232.85.
# Patient 185 (STROKE)                 has a length of stay of 3.96 days.
# Patient 73 (OTHER)  gets a bed at 232.85. waiting time: 2.02 days.
# 233.28: COMPLEX_NEURO arrival.
# Patient 58 (COMPLEX_NEURO)             arrives at 233.28.
# Patient 72 (OTHER)                 leaves at 233.60.
# Patient 72 (OTHER)                 has a length of stay of 1.11 days.
# Patient 74 (OTHER)  gets a bed at 233.60. waiting time: 2.57 days.
# Patient 189 (STROKE)                 leaves at 233.68.
# Patient 189 (STROKE)                 has a length of stay of 2.72 days.
# Patient 191 (STROKE)  gets a bed at 233.68. waiting time: 1.30 days.
# Patient 190 (STROKE)                 leaves at 233.71.
# Patient 190 (STROKE)                 has a length of stay of 1.56 days.
# Patient 58 (COMPLEX_NEURO)  gets a bed at 233.71. waiting time: 0.43 days.
# Patient 74 (OTHER)                 leaves at 234.47.
# Patient 74 (OTHER)                 has a length of stay of 0.87 days.
# 234.62: STROKE arrival.
# Patient 192 (STROKE)             arrives at 234.62.
# Patient 192 (STROKE)  gets a bed at 234.62. waiting time: 0.00 days.
# 234.82: OTHER arrival.
# Patient 75 (OTHER)             arrives at 234.82.
# 234.94: STROKE arrival.
# Patient 193 (STROKE)             arrives at 234.94.
# 235.39: STROKE arrival.
# Patient 194 (STROKE)             arrives at 235.39.
# Patient 191 (STROKE)                 leaves at 235.78.
# Patient 191 (STROKE)                 has a length of stay of 2.09 days.
# Patient 75 (OTHER)  gets a bed at 235.78. waiting time: 0.95 days.
# Patient 73 (OTHER)                 leaves at 235.83.
# Patient 73 (OTHER)                 has a length of stay of 2.99 days.
# Patient 193 (STROKE)  gets a bed at 235.83. waiting time: 0.89 days.
# 236.34: OTHER arrival.
# Patient 76 (OTHER)             arrives at 236.34.
# 236.67: STROKE arrival.
# Patient 195 (STROKE)             arrives at 236.67.
# 236.81: COMPLEX_NEURO arrival.
# Patient 59 (COMPLEX_NEURO)             arrives at 236.81.
# Patient 180 (STROKE)                 leaves at 237.35.
# Patient 180 (STROKE)                 has a length of stay of 10.64 days.
# Patient 194 (STROKE)  gets a bed at 237.35. waiting time: 1.96 days.
# 237.89: OTHER arrival.
# Patient 77 (OTHER)             arrives at 237.89.
# 238.08: STROKE arrival.
# Patient 196 (STROKE)             arrives at 238.08.
# 238.14: COMPLEX_NEURO arrival.
# Patient 60 (COMPLEX_NEURO)             arrives at 238.14.
# Patient 193 (STROKE)                 leaves at 238.22.
# Patient 193 (STROKE)                 has a length of stay of 2.39 days.
# Patient 76 (OTHER)  gets a bed at 238.22. waiting time: 1.88 days.
# 238.25: OTHER arrival.
# Patient 78 (OTHER)             arrives at 238.25.
# 238.28: STROKE arrival.
# Patient 197 (STROKE)             arrives at 238.28.
# 238.66: OTHER arrival.
# Patient 79 (OTHER)             arrives at 238.66.
# 238.86: STROKE arrival.
# Patient 198 (STROKE)             arrives at 238.86.
# Patient 192 (STROKE)                 leaves at 239.08.
# Patient 192 (STROKE)                 has a length of stay of 4.46 days.
# Patient 195 (STROKE)  gets a bed at 239.08. waiting time: 2.41 days.
# 239.22: OTHER arrival.
# Patient 80 (OTHER)             arrives at 239.22.
# Patient 76 (OTHER)                 leaves at 239.43.
# Patient 76 (OTHER)                 has a length of stay of 1.21 days.
# Patient 59 (COMPLEX_NEURO)  gets a bed at 239.43. waiting time: 2.62 days.
# 239.55: STROKE arrival.
# Patient 199 (STROKE)             arrives at 239.55.
# 239.59: STROKE arrival.
# Patient 200 (STROKE)             arrives at 239.59.
# Patient 71 (OTHER)                 leaves at 239.80.
# Patient 71 (OTHER)                 has a length of stay of 8.52 days.
# Patient 77 (OTHER)  gets a bed at 239.80. waiting time: 1.92 days.
# Patient 59 (COMPLEX_NEURO)                 leaves at 239.94.
# Patient 59 (COMPLEX_NEURO)                 has a length of stay of 0.51 days.
# Patient 196 (STROKE)  gets a bed at 239.94. waiting time: 1.86 days.
# Final summary: There were a total of 1400         patients in the system.
# {'n_stroke': 200,
#  'n_tia': 19,
#  'n_complex_neuro': 60,
#  'n_other': 80,
#  'n_patients': 359,
#  'n_stroke_discharged': 189,
#  'n_tia_discharged': 19,
#  'n_complex_neuro_discharged': 58,
#  'n_other_discharged': 75,
#  'n_discharged': 341}

# %% [markdown]
# ## TEST - Should only show TIA patients

# %%
M = 1_000_000
experiment = Experiment(iat_stroke=M, iat_complex_neuro=M, iat_other=M)
results = single_run(experiment)
results
# Out:
# 7.47: TIA arrival.
# Patient 1 (TIA)             arrives at 7.47.
# Patient 1 (TIA)  gets a bed at 7.47. waiting time: 0.00 days.
# Patient 1 (TIA)                 leaves at 8.52.
# Patient 1 (TIA)                 has a length of stay of 1.06 days.
# 11.02: TIA arrival.
# Patient 2 (TIA)             arrives at 11.02.
# Patient 2 (TIA)  gets a bed at 11.02. waiting time: 0.00 days.
# Patient 2 (TIA)                 leaves at 11.33.
# Patient 2 (TIA)                 has a length of stay of 0.31 days.
# 14.41: TIA arrival.
# Patient 3 (TIA)             arrives at 14.41.
# Patient 3 (TIA)  gets a bed at 14.41. waiting time: 0.00 days.
# Patient 3 (TIA)                 leaves at 14.78.
# Patient 3 (TIA)                 has a length of stay of 0.37 days.
# 19.33: TIA arrival.
# Patient 4 (TIA)             arrives at 19.33.
# Patient 4 (TIA)  gets a bed at 19.33. waiting time: 0.00 days.
# Patient 4 (TIA)                 leaves at 20.48.
# Patient 4 (TIA)                 has a length of stay of 1.15 days.
# 45.26: TIA arrival.
# Patient 5 (TIA)             arrives at 45.26.
# Patient 5 (TIA)  gets a bed at 45.26. waiting time: 0.00 days.
# Patient 5 (TIA)                 leaves at 49.49.
# Patient 5 (TIA)                 has a length of stay of 4.23 days.
# 63.50: TIA arrival.
# Patient 6 (TIA)             arrives at 63.50.
# Patient 6 (TIA)  gets a bed at 63.50. waiting time: 0.00 days.
# Patient 6 (TIA)                 leaves at 64.35.
# Patient 6 (TIA)                 has a length of stay of 0.85 days.
# 72.33: TIA arrival.
# Patient 7 (TIA)             arrives at 72.33.
# Patient 7 (TIA)  gets a bed at 72.33. waiting time: 0.00 days.
# Patient 7 (TIA)                 leaves at 75.80.
# Patient 7 (TIA)                 has a length of stay of 3.47 days.
# 111.08: TIA arrival.
# Patient 8 (TIA)             arrives at 111.08.
# Patient 8 (TIA)  gets a bed at 111.08. waiting time: 0.00 days.
# Patient 8 (TIA)                 leaves at 112.97.
# Patient 8 (TIA)                 has a length of stay of 1.89 days.
# 116.54: TIA arrival.
# Patient 9 (TIA)             arrives at 116.54.
# Patient 9 (TIA)  gets a bed at 116.54. waiting time: 0.00 days.
# Patient 9 (TIA)                 leaves at 119.27.
# Patient 9 (TIA)                 has a length of stay of 2.73 days.
# 142.47: TIA arrival.
# Patient 10 (TIA)             arrives at 142.47.
# Patient 10 (TIA)  gets a bed at 142.47. waiting time: 0.00 days.
# Patient 10 (TIA)                 leaves at 143.41.
# Patient 10 (TIA)                 has a length of stay of 0.94 days.
# 165.64: TIA arrival.
# Patient 11 (TIA)             arrives at 165.64.
# Patient 11 (TIA)  gets a bed at 165.64. waiting time: 0.00 days.
# Patient 11 (TIA)                 leaves at 166.59.
# Patient 11 (TIA)                 has a length of stay of 0.95 days.
# 182.45: TIA arrival.
# Patient 12 (TIA)             arrives at 182.45.
# Patient 12 (TIA)  gets a bed at 182.45. waiting time: 0.00 days.
# Patient 12 (TIA)                 leaves at 183.05.
# Patient 12 (TIA)                 has a length of stay of 0.60 days.
# 185.34: TIA arrival.
# Patient 13 (TIA)             arrives at 185.34.
# Patient 13 (TIA)  gets a bed at 185.34. waiting time: 0.00 days.
# Patient 13 (TIA)                 leaves at 186.02.
# Patient 13 (TIA)                 has a length of stay of 0.68 days.
# 210.21: TIA arrival.
# Patient 14 (TIA)             arrives at 210.21.
# Patient 14 (TIA)  gets a bed at 210.21. waiting time: 0.00 days.
# Patient 14 (TIA)                 leaves at 210.44.
# Patient 14 (TIA)                 has a length of stay of 0.23 days.
# 210.91: TIA arrival.
# Patient 15 (TIA)             arrives at 210.91.
# Patient 15 (TIA)  gets a bed at 210.91. waiting time: 0.00 days.
# Patient 15 (TIA)                 leaves at 211.31.
# Patient 15 (TIA)                 has a length of stay of 0.40 days.
# 211.40: TIA arrival.
# Patient 16 (TIA)             arrives at 211.40.
# Patient 16 (TIA)  gets a bed at 211.40. waiting time: 0.00 days.
# 213.66: TIA arrival.
# Patient 17 (TIA)             arrives at 213.66.
# Patient 17 (TIA)  gets a bed at 213.66. waiting time: 0.00 days.
# Patient 16 (TIA)                 leaves at 216.26.
# Patient 16 (TIA)                 has a length of stay of 4.87 days.
# 222.65: TIA arrival.
# Patient 18 (TIA)             arrives at 222.65.
# Patient 18 (TIA)  gets a bed at 222.65. waiting time: 0.00 days.
# Patient 17 (TIA)                 leaves at 223.76.
# Patient 17 (TIA)                 has a length of stay of 10.10 days.
# Patient 18 (TIA)                 leaves at 224.23.
# Patient 18 (TIA)                 has a length of stay of 1.58 days.
# 229.17: TIA arrival.
# Patient 19 (TIA)             arrives at 229.17.
# Patient 19 (TIA)  gets a bed at 229.17. waiting time: 0.00 days.
# Patient 19 (TIA)                 leaves at 230.29.
# Patient 19 (TIA)                 has a length of stay of 1.13 days.
# Final summary: There were a total of 76         patients in the system.
# {'n_stroke': 0,
#  'n_tia': 19,
#  'n_complex_neuro': 0,
#  'n_other': 0,
#  'n_patients': 19,
#  'n_stroke_discharged': 0,
#  'n_tia_discharged': 19,
#  'n_complex_neuro_discharged': 0,
#  'n_other_discharged': 0,
#  'n_discharged': 19}
